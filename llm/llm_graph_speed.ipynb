# %% [markdown]
# <a href="https://colab.research.google.com/github/tomasonjo/blogs/blob/master/llm/llm_graph_speed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --quiet langchain-experimental langchain-openai

# %%
import getpass
import os

os.environ["OPENAI_API_KEY"] = getpass.getpass()
# Out:
# ··········

# %%
import pandas as pd

news = pd.read_csv(
    "https://raw.githubusercontent.com/tomasonjo/blog-datasets/main/news_articles.csv"
)

# %%
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(temperature=0, model_name="gpt-4o")

llm_transformer = LLMGraphTransformer(
    llm=llm,
    node_properties=["description"],
    relationship_properties=["description"]
)

# %%
from langchain_core.documents import Document

documents = [Document(page_content=t) for t in news.text][:20]

# %%
# %time llm_transformer.convert_to_graph_documents(documents)
# Out:
# CPU times: user 2.27 s, sys: 172 ms, total: 2.45 s
# Wall time: 2min 23s
# [GraphDocument(nodes=[Node(id='Jhvephoto', type='Company'), Node(id='Chevron', type='Company'), Node(id='Cvx', type='Stock'), Node(id='Q2 Consensus Earnings Estimates', type='Financial metric')], relationships=[Relationship(source=Node(id='Chevron', type='Company'), target=Node(id='Cvx', type='Stock'), type='HAS_STOCK'), Relationship(source=Node(id='Cvx', type='Stock'), target=Node(id='Q2 Consensus Earnings Estimates', type='Financial metric'), type='HAS_METRIC', properties={'description': 'risen sharply (~25%) during the past 90-days'})], source=Document(page_content='JHVEPhoto Like many companies in the O&G sector, the stock of Chevron (NYSE:CVX) has declined about 10% over the past 90-days despite the fact that Q2 consensus earnings estimates have risen sharply (~25%) during that same time frame. Over the years, Chevron has kept a very strong balance sheet. That allowed the...')),
#  GraphDocument(nodes=[Node(id='Firstenergy', type='Organization', properties={'description': 'utilities provider'}), Node(id='Rtt News', type='Organization')], relationships=[Relationship(source=Node(id='Firstenergy', type='Organization'), target=Node(id='Rtt News', type='Organization'), type='REPORTED', properties={'description': 'FirstEnergy posted its earnings results on Tuesday, reporting $0.53 earnings per share for the quarter, topping the consensus estimate of $0.52 by $0.01. FirstEnergy had a net margin of 10.85% and a return on equity of 17.17%.'})], source=Document(page_content='FirstEnergy (NYSE:FE – Get Rating) posted its earnings results on Tuesday. The utilities provider reported $0.53 earnings per share for the quarter, topping the consensus estimate of $0.52 by $0.01, RTT News reports. FirstEnergy had a net margin of 10.85% and a return on equity of 17.17%. During the same period...\nIf the content contained herein violates any of your rights, including those of copyright, you are requested to immediately notify us using via the following email address operanews-external(at)opera.com\nTop News')),
#  GraphDocument(nodes=[Node(id='Dáil', type='Organization'), Node(id='Sinn Féin', type='Organization'), Node(id='John Brady', type='Person'), Node(id='Minister For Housing', type='Person'), Node(id='Darragh O’Brien', type='Person'), Node(id='Retained Firefighters', type='Organization'), Node(id='Ireland', type='Location'), Node(id='Pearse Doherty', type='Person'), Node(id='Leinster House', type='Location'), Node(id='Government', type='Organization'), Node(id='Ceann Comhairle', type='Person'), Node(id='Seán Ó Fearghaíl', type='Person'), Node(id='Opposition', type='Organization'), Node(id='Unions', type='Organization'), Node(id='State’S Industrial Relations Process', type='Concept')], relationships=[Relationship(source=Node(id='John Brady', type='Person'), target=Node(id='Darragh O’Brien', type='Person'), type='PLACED', properties={'description': 'placed an on-call pager in front of Darragh O’Brien during a debate on retained firefighters'}), Relationship(source=Node(id='Darragh O’Brien', type='Person'), target=Node(id='John Brady', type='Person'), type='ACCUSED', properties={'description': 'accused John Brady of an act of theatre that was obviously choreographed'}), Relationship(source=Node(id='Retained Firefighters', type='Organization'), target=Node(id='Ireland', type='Location'), type='LOCATED_IN', properties={'description': 'around 2,000 retained firefighters around the country'}), Relationship(source=Node(id='Retained Firefighters', type='Organization'), target=Node(id='Industrial Action', type='Concept'), type='ENGAGED_IN', properties={'description': 'staged a second day of industrial action and are due to start all out-strike action'}), Relationship(source=Node(id='Pearse Doherty', type='Person'), target=Node(id='Dáil', type='Organization'), type='SPOKE_IN', properties={'description': 'spoke in the Dáil about firefighters marching on Leinster House and being very angry at the Government'}), Relationship(source=Node(id='Firefighters', type='Organization'), target=Node(id='Leinster House', type='Location'), type='MARCHED_ON', properties={'description': 'firefighters marched on Leinster House'}), Relationship(source=Node(id='Pearse Doherty', type='Person'), target=Node(id='Darragh O’Brien', type='Person'), type='ASKED', properties={'description': 'asked Darragh O’Brien to make an improved offer in relation to pay for retained firefighters'}), Relationship(source=Node(id='Pearse Doherty', type='Person'), target=Node(id='Darragh O’Brien', type='Person'), type='CHALLENGED', properties={'description': 'challenged Darragh O’Brien to meet with the firefighters'}), Relationship(source=Node(id='John Brady', type='Person'), target=Node(id='Darragh O’Brien', type='Person'), type='PLACED', properties={'description': 'placed the pager on the desk in front of Darragh O’Brien'}), Relationship(source=Node(id='Ceann Comhairle', type='Person'), target=Node(id='John Brady', type='Person'), type='SAID', properties={'description': 'said John Brady was completely out of order'}), Relationship(source=Node(id='Darragh O’Brien', type='Person'), target=Node(id='John Brady', type='Person'), type='ACCUSED', properties={'description': 'accused John Brady of engaging in an act of theatre which was obviously choreographed'}), Relationship(source=Node(id='Darragh O’Brien', type='Person'), target=Node(id='Firefighters', type='Organization'), type='REGARD', properties={'description': 'said he had immense regard for firefighters'}), Relationship(source=Node(id='Darragh O’Brien', type='Person'), target=Node(id='Unions', type='Organization'), type='ENCOURAGED', properties={'description': 'encouraged the unions to re-engage with the State’s industrial relations process'}), Relationship(source=Node(id='Darragh O’Brien', type='Person'), target=Node(id='Sinn Féin', type='Organization'), type='ACCUSED', properties={'description': 'accused Sinn Féin of using the issue for their own political gain'})], source=Document(page_content='The Dáil was almost suspended on Th ...
#  GraphDocument(nodes=[Node(id='Epic', type='Company'), Node(id='Metahuman Animator', type='Tool', properties={'description': 'A tool designed to capture an actor’s facial performance using a device as simple as an iPhone and apply it to a hyperrealistic MetaHuman in the Unreal Engine in minutes.'}), Node(id='Unreal Engine', type='Software'), Node(id='Game Developers Conference', type='Event'), Node(id='March', type='Date'), Node(id='Blue Dot', type='Short film'), Node(id='3Lateral', type='Team'), Node(id='Radivoje Bukvić', type='Person'), Node(id='Mika Antić', type='Person'), Node(id='Live Link Face Ios App', type='Software'), Node(id='Iphone 12', type='Device'), Node(id='Metahuman Hub', type='Website'), Node(id='Epic Developer Community', type='Community')], relationships=[Relationship(source=Node(id='Epic', type='Company'), target=Node(id='Metahuman Animator', type='Tool'), type='RELEASED'), Relationship(source=Node(id='Metahuman Animator', type='Tool'), target=Node(id='Unreal Engine', type='Software'), type='INTEGRATES_WITH'), Relationship(source=Node(id='Metahuman Animator', type='Tool'), target=Node(id='Game Developers Conference', type='Event'), type='DETAILED_AT', properties={'description': 'Detailed at the Game Developers Conference in March.'}), Relationship(source=Node(id='Epic', type='Company'), target=Node(id='Blue Dot', type='Short film'), type='PRODUCED'), Relationship(source=Node(id='3Lateral', type='Team'), target=Node(id='Blue Dot', type='Short film'), type='PRODUCED'), Relationship(source=Node(id='Radivoje Bukvić', type='Person'), target=Node(id='Blue Dot', type='Short film'), type='STARS_IN'), Relationship(source=Node(id='Mika Antić', type='Person'), target=Node(id='Blue Dot', type='Short film'), type='BASED_ON', properties={'description': 'Based on a poem by Mika Antić.'}), Relationship(source=Node(id='Metahuman Animator', type='Tool'), target=Node(id='Live Link Face Ios App', type='Software'), type='COMBINES_WITH'), Relationship(source=Node(id='Metahuman Animator', type='Tool'), target=Node(id='Iphone 12', type='Device'), type='COMPATIBLE_WITH'), Relationship(source=Node(id='Metahuman Animator', type='Tool'), target=Node(id='Metahuman Hub', type='Website'), type='DOCUMENTED_ON'), Relationship(source=Node(id='Metahuman Hub', type='Website'), target=Node(id='Epic Developer Community', type='Community'), type='PART_OF')], source=Document(page_content='Today, Epic is releasing a new tool designed to capture an actor’s facial performance using a device as simple as an iPhone and apply it to a hyperrealistic “MetaHuman” in the Unreal Engine in “minutes.” The feature, dubbed MetaHuman Animator, was detailed at the Game Developers Conference in March but is now available for developers to try out for themselves. Epic has also released a new video today produced by one of its internal teams to show what the tool is capable of.\nWhile Epic’s short film shows off some impressively subtle facial animation, the big benefit the company is emphasizing is the speed with which MetaHuman Animator produces results. “The animation is produced locally using GPU hardware, with the final animation available in minutes,” the company’s press release reads. That has the potential to not just save a studio money by making performance capture more efficient but also, Epic argues, it could allow them to experiment and be more creative.\n“Need an actor to give you more, dig into a different emotion, or simply explore a new direction?” Epic’s press release asks. “Have them do another take. You’ll be able to review the results in about the time it takes to make a cup of coffee.” Facial animation can be applied to a MetaHuman character “in just a few clicks,” Epic says, and the system is even smart enough to animate a character’s tongue based on the performance’s audio.\nPerformance capture using iPhones has been possible in the Unreal Engine since at least 2020 with the launch of Epic’s Live Link Face iOS app, but now, it’s combined with ...
#  GraphDocument(nodes=[Node(id='European Commission', type='Organization'), Node(id='Huawei Technologies Co.', type='Organization'), Node(id='Zte Corp.', type='Organization'), Node(id='European Union', type='Organization'), Node(id='Us', type='Organization'), Node(id='China', type='Organization'), Node(id='Tiktok Inc.', type='Organization'), Node(id='Thomas Seal', type='Person'), Node(id='Alberto Nardelli', type='Person')], relationships=[Relationship(source=Node(id='European Commission', type='Organization'), target=Node(id='Huawei Technologies Co.', type='Organization'), type='BAN', properties={'description': 'The European Commission is planning to ban equipment from Huawei Technologies Co. from its own internal telecommunications networks.'}), Relationship(source=Node(id='European Commission', type='Organization'), target=Node(id='Zte Corp.', type='Organization'), type='BAN', properties={'description': 'The European Commission is planning to ban equipment from ZTE Corp. from its own internal telecommunications networks.'}), Relationship(source=Node(id='European Union', type='Organization'), target=Node(id='Huawei Technologies Co.', type='Organization'), type='CONSIDER_HIGH_RISK', properties={'description': 'The European Union considers Huawei Technologies Co. a high-risk vendor.'}), Relationship(source=Node(id='European Union', type='Organization'), target=Node(id='Zte Corp.', type='Organization'), type='CONSIDER_HIGH_RISK', properties={'description': 'The European Union considers ZTE Corp. a high-risk vendor.'}), Relationship(source=Node(id='Us', type='Organization'), target=Node(id='China', type='Organization'), type='DETERIORATED_RELATIONSHIP', properties={'description': 'The relationship between the US and China has deteriorated.'}), Relationship(source=Node(id='Us', type='Organization'), target=Node(id='Huawei Technologies Co.', type='Organization'), type='BLOCK', properties={'description': 'The US has blocked Chinese technology from core telecommunications networks because of spying concerns.'}), Relationship(source=Node(id='Us', type='Organization'), target=Node(id='Zte Corp.', type='Organization'), type='BLOCK', properties={'description': 'The US has blocked Chinese technology from core telecommunications networks because of spying concerns.'}), Relationship(source=Node(id='European Commission', type='Organization'), target=Node(id='Tiktok Inc.', type='Organization'), type='BLOCK', properties={'description': 'The European Commission blocked its staff from using TikTok Inc. over security concerns related to the social-media app’s data-collection practices.'}), Relationship(source=Node(id='Thomas Seal', type='Person'), target=Node(id='European Commission', type='Organization'), type='ASSISTED', properties={'description': 'Thomas Seal assisted in the matter.'}), Relationship(source=Node(id='Alberto Nardelli', type='Person'), target=Node(id='European Commission', type='Organization'), type='ASSISTED', properties={'description': 'Alberto Nardelli assisted in the matter.'})], source=Document(page_content='The European Commission is planning to ban equipment from Chinese vendors Huawei Technologies Co. and ZTE Corp. from its own internal telecommunications networks, people familiar with the matter said.\nThe ban comes ahead of an anticipated update to the European Union’s guidance on 5G mobile networks within the bloc that’s expected to more forcefully encourage members to phase out equipment from the companies, which it considers high risk, the people said, asking not to be identified because the plan isn’t yet public.\nAs the relationship between the US and its allies and China has deteriorated, countries have blocked Chinese technology from their core telecommunications networks because of spying concerns. The move is similar to the commission’s decision to block its staff from using TikTok Inc. over security concerns related to the social-media app’s data-collection practices.\nRead More: TikTok Banned From EU Commissio ...
#  GraphDocument(nodes=[Node(id='Jude Bellingham', type='Person'), Node(id='Real Madrid', type='Organization'), Node(id='Borussia Dortmund', type='Organization'), Node(id='Jesus Vallejo', type='Person'), Node(id='Zidane', type='Person')], relationships=[Relationship(source=Node(id='Jude Bellingham', type='Person'), target=Node(id='Real Madrid', type='Organization'), type='TRANSFER', properties={'description': 'Jude Bellingham moved to Real Madrid.'}), Relationship(source=Node(id='Jude Bellingham', type='Person'), target=Node(id='Borussia Dortmund', type='Organization'), type='PERMISSION', properties={'description': 'Jude Bellingham spoke with Real Madrid after getting permission from Borussia Dortmund.'}), Relationship(source=Node(id='Jude Bellingham', type='Person'), target=Node(id='Jesus Vallejo', type='Person'), type='CONTACT', properties={'description': 'Jude Bellingham contacted Jesus Vallejo to ask for the No.5 shirt.'}), Relationship(source=Node(id='Jude Bellingham', type='Person'), target=Node(id='Zidane', type='Person'), type='ADMIRE', properties={'description': 'Jude Bellingham admires Zidane and his legacy at Real Madrid.'})], source=Document(page_content='Jude Bellingham has also insisted his move to Real Madrid had nothing to do with money, as he explained how his transfer was wrapped up so quickly.\n“Money is not a thing for me,” he said.\n“I dont think about money at all when I make these kinds of decisions. I never have and I never will. I play the game purely out of love.\n“I spoke with people from Real Madrid when I was given permission by Borussia Dortmund and I love the feeling I got from the club. I couldn’t hide it. I told them straight away what I felt and after that happened on Monday it all happened quickly.”\nHe also opened up on how he was given the No.5 shirt, which was worn by defender Jesus Vallejo last season, and what it means to him to have Zidane’s old number on his back.\n“For a start I’d like to thank Jesus Vallejo for letting me wear the No.5,” he explained.\n“I contacted him just to see if it was OK with him and he was just a brilliant guy, he let me wear it and was just so nice about it, so I’m very grateful to him.\n“I’ve said in many interviews how much I admire Zidane, the legacy he has at the club and the legacy of his number.\n“I’m not trying to be the same as him, I’m just trying to be Jude, but it’s definitely a bit of a homage to how great he was.\n“As for the 22, it’s a number that has a lot of meaning to me and in my heart I’m still a 22, I’m just wearing the No.5 on my back.\n“We’ll see what happens in the future, but right now I’m really happy to be given this honour of wearing this number.”')),
#  GraphDocument(nodes=[Node(id='Ryanair', type='Organization'), Node(id='Aidan Murray', type='Person'), Node(id='Darrell Hughes', type='Person'), Node(id='The Independent', type='Organization'), Node(id='The Financial Times', type='Organization'), Node(id='Bbc', type='Organization'), Node(id='Royal Aeronautical Society', type='Organization')], relationships=[Relationship(source=Node(id='Ryanair', type='Organization'), target=Node(id='Aidan Murray', type='Person'), type='EMPLOYED', properties={'description': 'Chief Pilot, appointed in 2020, with the airline for 28 years'}), Relationship(source=Node(id='Aidan Murray', type='Person'), target=Node(id='Ryanair', type='Organization'), type='HARASSED', properties={'description': 'Alleged sexual harassment of female colleagues'}), Relationship(source=Node(id='Ryanair', type='Organization'), target=Node(id='Aidan Murray', type='Person'), type='TERMINATED', properties={'description': 'Terminated with immediate effect for inappropriate and unacceptable behaviour'}), Relationship(source=Node(id='Darrell Hughes', type='Person'), target=Node(id='Aidan Murray', type='Person'), type='TERMINATED', properties={'description': 'Announced the termination of Aidan Murray'}), Relationship(source=Node(id='The Independent', type='Organization'), target=Node(id='Aidan Murray', type='Person'), type='REPORTED', properties={'description': 'Reported harassment of nine junior colleagues'}), Relationship(source=Node(id='The Financial Times', type='Organization'), target=Node(id='Aidan Murray', type='Person'), type='REPORTED', properties={'description': 'Reported that Aidan Murray has seven days to appeal against dismissal'}), Relationship(source=Node(id='Bbc', type='Organization'), target=Node(id='Aidan Murray', type='Person'), type='CONTACTED', properties={'description': 'Attempted to contact Aidan Murray for comment'}), Relationship(source=Node(id='Royal Aeronautical Society', type='Organization'), target=Node(id='Sexual Harassment', type='Concept'), type='REPORTED', properties={'description': 'Reported extremely concerning reports of sexism and sexual harassment by many female pilots'})], source=Document(page_content='Reuters\nRyanair has sacked its chief pilot after an investigation into his alleged sexual harassment of female colleagues.\nThe airline told staff that he had been fired for "a pattern of repeated inappropriate and unacceptable behaviour towards a number of female pilots".\nThe chief pilot, named in reports as Aidan Murray was appointed in 2020 and had been with the airline for 28 years.\nRyanair declined to comment "on queries relating to individual employees".\nAccording to The Independent, Mr Murray allegedly harassed nine junior colleagues, including sending text messages to some with comments on their bodies.\nMr Murray, 58, is also accused of altering flight rosters to fly with certain female pilots.\nIn a note to staff, Ryanair\'s chief people officer, Darrell Hughes, said Mr Murray\'s employment had been "terminated with immediate effect".\nAn investigation found his behaviour "was in breach of our anti-harassment policy". Ryanair said staff should be able to come to work "in a safe and secure environment".\n"We would ask all of you to respect the privacy and integrity of those brave individuals who came forward to assist us in this investigation," Mr Hughes added.\nThe Financial Times reported that Mr Murray has seven days to launch an appeal against his dismissal.\nThe BBC has attempted to contact Mr Murray for comment.\nThe job of chief pilot is an important one. The holder is both a highly qualified airline captain and a manager, responsible for overseeing other pilots based at a hub airport.\nThey are usually in charge of issues such as training, flight coordination and rostering as well as addressing personal issues. They can also represent the airline in disciplinary issues.\nAs such, they have a lot of power over their fellow pilots, particularly more junior ones seeking prom ...
#  GraphDocument(nodes=[Node(id='Keybank', type='Organization', properties={'description': "One of the nation's largest bank-based financial services companies, headquartered in Cleveland, Ohio."}), Node(id='American Fork Branch', type='Location', properties={'description': "KeyBank's first new branch in the Western half of the U.S. in more than a decade, located at 717 West Main in American Fork."}), Node(id='Drew Yergensen', type='Person', properties={'description': 'KeyBank Utah market president and commercial banking leader.'}), Node(id='Five.12 Foundation', type='Organization', properties={'description': 'Based in Alpine, Utah, organizes and distributes weekend food bags to students in need at four American Fork elementary schools.'}), Node(id='Jason Scorup', type='Person', properties={'description': 'KeyBank American Fork branch manager.'}), Node(id='Laura Suter', type='Person', properties={'description': 'Regional Communications Manager at KeyBank.'}), Node(id='Keycorp', type='Organization', properties={'description': "KeyBank's parent company, with roots tracing back nearly 200 years to Albany, New York."})], relationships=[Relationship(source=Node(id='Keybank', type='Organization'), target=Node(id='American Fork Branch', type='Location'), type='HAS_BRANCH', properties={'description': 'Commemorated the one-year anniversary of its American Fork branch.'}), Relationship(source=Node(id='Keybank', type='Organization'), target=Node(id='Drew Yergensen', type='Person'), type='EMPLOYS', properties={'description': 'Drew Yergensen is the Utah market president and commercial banking leader.'}), Relationship(source=Node(id='Keybank', type='Organization'), target=Node(id='Five.12 Foundation', type='Organization'), type='DONATED_TO', properties={'description': 'KeyBank made a $10,000 donation to the Five.12 Foundation.'}), Relationship(source=Node(id='Keybank', type='Organization'), target=Node(id='Jason Scorup', type='Person'), type='EMPLOYS', properties={'description': 'Jason Scorup is the American Fork branch manager.'}), Relationship(source=Node(id='Keybank', type='Organization'), target=Node(id='Laura Suter', type='Person'), type='EMPLOYS', properties={'description': 'Laura Suter is the Regional Communications Manager.'}), Relationship(source=Node(id='Keybank', type='Organization'), target=Node(id='Keycorp', type='Organization'), type='SUBSIDIARY_OF', properties={'description': 'KeyBank is a subsidiary of KeyCorp.'})], source=Document(page_content='CLEVELAND, UT / ACCESSWIRE / June 15, 2023 / KeyBank recently commemorated the one-year anniversary of its American Fork branch - the company\'s first new branch in the Western half of the U.S. in more than a decade. The celebration included a networking event with the branch\'s business clients and the American Fork Chamber of Commerce, as well as a $10,000 donation to the Five.12 Foundation.\n"We\'ve had a great first year in American Fork," said Drew Yergensen, KeyBank Utah market president and commercial banking leader. "We have really enjoyed meeting and working more closely with our new neighbors, clients and community partners, and we look forward to strengthening those relationships even further in the coming years."\nThe American Fork branch highlights KeyBank\'s state-of-the-art financial wellness center model, which is staffed with financial wellness consultants rather than a traditional teller line. All transactions are completed at desks, where consultants also conduct comprehensive financial wellness reviews and discussions. Clients can also meet with specialists in mortgage, investments, business banking and more at the location.\nThe branch features digital video screens and a client hospitality space that also serves as an area for financial seminars and group presentations with clients and the public, as well as a drive-up teller line, ATM and complimentary parking. In addition to helping individuals and families achieve their financial goals, the branch also serves c ...
#  GraphDocument(nodes=[Node(id='Vivo X90S', type='Product', properties={'description': 'A new smartphone teased by Jia Jingdong, featuring a Zeiss-tuned triple rear camera unit and expected to run on MediaTek Dimensity 9200+ SoC.'}), Node(id='Jia Jingdong', type='Person', properties={'description': "Vivo's Vice President and General Manager of Product Strategy."}), Node(id='Vivo', type='Organization', properties={'description': 'A smartphone manufacturer.'}), Node(id='Weibo', type='Platform', properties={'description': 'A Chinese microblogging platform.'}), Node(id='Vivo X90', type='Product', properties={'description': 'A smartphone in the Vivo X90 series, featuring MediaTek Dimensity 9200 SoC and Wi-Fi 6 connectivity.'}), Node(id='Vivo X90 Pro', type='Product', properties={'description': 'A smartphone in the Vivo X90 series, recently debuted in India.'}), Node(id='Mediatek Dimensity 9200+ Soc', type='Technology', properties={'description': 'A system on chip expected to power the Vivo X90s.'}), Node(id='Mediatek Dimensity 9200 Soc', type='Technology', properties={'description': 'A system on chip found on the Vivo X90.'}), Node(id='Zeiss', type='Organization', properties={'description': 'A company known for its camera lens technology.'}), Node(id='Tenaa', type='Organization', properties={'description': 'A Chinese regulatory body that lists specifications of electronic devices.'})], relationships=[Relationship(source=Node(id='Jia Jingdong', type='Person'), target=Node(id='Vivo', type='Organization'), type='AFFILIATION', properties={'description': 'Vice President and General Manager of Product Strategy.'}), Relationship(source=Node(id='Jia Jingdong', type='Person'), target=Node(id='Weibo', type='Platform'), type='POSTED_ON', properties={'description': 'Teased the Vivo X90s on Weibo.'}), Relationship(source=Node(id='Vivo X90S', type='Product'), target=Node(id='Vivo', type='Organization'), type='MANUFACTURER', properties={'description': 'Manufactured by Vivo.'}), Relationship(source=Node(id='Vivo X90S', type='Product'), target=Node(id='Vivo X90', type='Product'), type='SERIES', properties={'description': 'Part of the Vivo X90 series.'}), Relationship(source=Node(id='Vivo X90S', type='Product'), target=Node(id='Vivo X90 Pro', type='Product'), type='SERIES', properties={'description': 'Part of the Vivo X90 series.'}), Relationship(source=Node(id='Vivo X90S', type='Product'), target=Node(id='Mediatek Dimensity 9200+ Soc', type='Technology'), type='POWERED_BY', properties={'description': 'Expected to run on MediaTek Dimensity 9200+ SoC.'}), Relationship(source=Node(id='Vivo X90', type='Product'), target=Node(id='Mediatek Dimensity 9200 Soc', type='Technology'), type='POWERED_BY', properties={'description': 'Runs on MediaTek Dimensity 9200 SoC.'}), Relationship(source=Node(id='Vivo X90S', type='Product'), target=Node(id='Zeiss', type='Organization'), type='FEATURES', properties={'description': 'Features a Zeiss-tuned triple rear camera unit.'}), Relationship(source=Node(id='Vivo X90S', type='Product'), target=Node(id='Tenaa', type='Organization'), type='LISTED_BY', properties={'description': 'Listed by TENAA with specifications.'})], source=Document(page_content="Vivo X90s has been teased by Jia Jingdong, Vivo's Vice President and General Manager of Product Strategy via Weibo on Thursday. The new smartphone has a design similar to its Vivo X90 series siblings — Vivo X90 and Vivo X90 Pro. The Vivo X90s is shown to have a Zeiss-tuned triple rear camera unit. The upcoming model is expected to retain the key specification of the Vivo X90. Meanwhile, Chinese tipsters have leaked the specifications of the upcoming handset. The Vivo X90s is said to run on MediaTek Dimensity 9200+ SoC and could be offered in four different colour options.\nJia Jingdong posted an image of the Vivo X90s on the Chinese microblogging platform providing us a glimpse of the design from the rear. The render shows the handset in a white finish with rounded corners. The  ...
#  GraphDocument(nodes=[Node(id='Xpeng', type='Organization'), Node(id='Beijing', type='Location'), Node(id='Tesla', type='Organization')], relationships=[Relationship(source=Node(id='Xpeng', type='Organization'), target=Node(id='Beijing', type='Location'), type='LAUNCH', properties={'description': 'assisted-driving technology launched in Beijing and three other cities'}), Relationship(source=Node(id='Xpeng', type='Organization'), target=Node(id='Tesla', type='Organization'), type='RIVAL')], source=Document(page_content='Chinese electric-vehicle maker\nXPeng\nsaid Thursday its assisted-driving technology has been launched in Beijing and three other cities. The\nTesla\nrival’s stock was rising in premarket trading.')),
#  GraphDocument(nodes=[Node(id='Bank Of America', type='Organization', properties={'description': "One of the world's leading financial institutions, serving individual consumers, small and middle-market businesses and large corporations with a full range of banking, investing, asset management and other financial and risk management products and services."}), Node(id='Tram Nguyen', type='Person', properties={'description': 'Global Head of Strategic and Sustainable Investments at Bank of America.'}), Node(id='Nasir Qadree', type='Person', properties={'description': 'Founder of Zeal and a graduate of a Historically Black College and University (HBCU).'}), Node(id='Zeal', type='Organization', properties={'description': 'Provides overlooked founders with the resources they need to scale towards their next stage of growth.'}), Node(id='Esusu', type='Organization', properties={'description': 'One of the few Black-owned unicorns, which provides tools to help immigrants and minorities to provide rent reporting and data solutions for credit building.'}), Node(id='Chingona Ventures', type='Organization', properties={'description': 'Led by General Partner Samara Hernandez, targets founders with unique backgrounds creating businesses in markets that are often overlooked.'}), Node(id='Samara Hernandez', type='Person', properties={'description': 'General Partner of Chingona Ventures.'}), Node(id='Papaya', type='Organization', properties={'description': 'A bilingual STEM tutoring organization to close the educational gap for underserved students.'}), Node(id='Anu Ahluwalia', type='Person', properties={'description': 'Contact person for reporters at Bank of America.'})], relationships=[Relationship(source=Node(id='Bank Of America', type='Organization'), target=Node(id='Tram Nguyen', type='Person'), type='EMPLOYS', properties={'description': 'Global Head of Strategic and Sustainable Investments.'}), Relationship(source=Node(id='Nasir Qadree', type='Person'), target=Node(id='Zeal', type='Organization'), type='FOUNDED'), Relationship(source=Node(id='Zeal', type='Organization'), target=Node(id='Esusu', type='Organization'), type='INVESTED_IN'), Relationship(source=Node(id='Bank Of America', type='Organization'), target=Node(id='Chingona Ventures', type='Organization'), type='INVESTED_IN'), Relationship(source=Node(id='Chingona Ventures', type='Organization'), target=Node(id='Papaya', type='Organization'), type='INVESTED_IN'), Relationship(source=Node(id='Chingona Ventures', type='Organization'), target=Node(id='Samara Hernandez', type='Person'), type='LED_BY'), Relationship(source=Node(id='Bank Of America', type='Organization'), target=Node(id='Anu Ahluwalia', type='Person'), type='CONTACT')], source=Document(page_content='Investments in Diverse-led Funds Result in Capital Deployed to Over 1,000 Companies Across the U.S.\nNEW YORK, June 15, 2023 /PRNewswire/ -- Bank of America today announced that it has committed more than $500 million in equity investments to minority- and women-led funds, more than doubling its initial $200 million commitment.\nThe bank has committed equity to more than 150 funds, which to date have invested in over 1,000 companies that span 40 states. These companies are led by 1,500 diverse entrepreneurs and employ over 21,000 people.\n"We work across our company to address critical needs in our communities, including the lack of access to capital that diverse business owners face as they start or grow their businesses," said Tram Nguyen, Global Head of Strategic and Sustainable Investments at Bank of America. "We want to empower the talented fund managers who keenly understand how to identify and support those business owners. Each time we support a minority- or women-led fund, they in turn support diverse entrepreneurs, which ultimately helps us toward achieving our goal to advance racial equality and economic opportunity."\nNot only are fund managers breaking down barriers themselves, but they are also investing in compan ...
#  GraphDocument(nodes=[Node(id='Unitedhealth Group Inc.', type='Organization', properties={'description': 'Health insurer'}), Node(id='John Rex', type='Person', properties={'description': 'Chief Financial Officer of UnitedHealth Group Inc.'}), Node(id='Goldman Sachs Investor Conference', type='Event'), Node(id='Oppenheimer', type='Organization'), Node(id='Michael Wiederhorn', type='Person', properties={'description': 'Analyst at Oppenheimer'}), Node(id='Humana Inc.', type='Organization', properties={'description': 'Health insurer with large Medicare Advantage presence'}), Node(id='Centene Corp.', type='Organization', properties={'description': 'Health insurer in the Medicare Advantage business'}), Node(id='Elevance Health Inc.', type='Organization', properties={'description': 'Health insurer in the Medicare Advantage business'}), Node(id='Cvs Health Corp.', type='Organization', properties={'description': 'Health insurer in the Medicare Advantage business'}), Node(id='Dow Jones Industrial Average', type='Index'), Node(id='S&P 500', type='Index'), Node(id='Walgreens Boots Alliance Inc.', type='Organization')], relationships=[Relationship(source=Node(id='Unitedhealth Group Inc.', type='Organization'), target=Node(id='Dow Jones Industrial Average', type='Index'), type='COMPONENT', properties={'description': "UnitedHealth's stock is the highest-priced component of the Dow"}), Relationship(source=Node(id='Unitedhealth Group Inc.', type='Organization'), target=Node(id='S&P 500', type='Index'), type='COMPONENT', properties={'description': "UnitedHealth's stock is among the worst performers in the S&P 500"}), Relationship(source=Node(id='John Rex', type='Person'), target=Node(id='Goldman Sachs Investor Conference', type='Event'), type='ATTENDED', properties={'description': 'John Rex spoke about pent-up demand for surgeries'}), Relationship(source=Node(id='Michael Wiederhorn', type='Person'), target=Node(id='Unitedhealth Group Inc.', type='Organization'), type='COMMENTED', properties={'description': "Believed UnitedHealth's comments will weigh on the entire sector"}), Relationship(source=Node(id='Humana Inc.', type='Organization'), target=Node(id='S&P 500', type='Index'), type='COMPONENT', properties={'description': "Humana's stock was the S&P 500's biggest decliner"}), Relationship(source=Node(id='Centene Corp.', type='Organization'), target=Node(id='S&P 500', type='Index'), type='COMPONENT', properties={'description': "Centene's stock was among the S&P 500's big losers"}), Relationship(source=Node(id='Elevance Health Inc.', type='Organization'), target=Node(id='S&P 500', type='Index'), type='COMPONENT', properties={'description': "Elevance Health's stock was among the S&P 500's big losers"}), Relationship(source=Node(id='Cvs Health Corp.', type='Organization'), target=Node(id='S&P 500', type='Index'), type='COMPONENT', properties={'description': "CVS Health's stock was among the S&P 500's big losers"})], source=Document(page_content='Health insurer\'s stock suffers second-biggest price decline since it starting trading 39 years ago\nShares of UnitedHealth Group Inc. took a dive Wednesday to suffer their worst percentage performance in three years, after the health insurer said it was facing higher costs from pent-up demand for surgeries.\nThe stock (UNH) was by far the biggest decliner within the Dow Jones Industrial Average , and was among the worst performers in the S&P 500 , along with fellow health insurers with Medicare Advantage exposure.\nUnitedHealth\'s stock dropped 6.4% to a one-year closing low of $459.86. That was the biggest percentage decline since it sank 7.2% on June 11, 2020.\nThe stock\'s price decline of $31.45 was the second-biggest since it started trading in October 1984, behind only the $47.00 (17.3%) plunge on March 16, 2020, at the height of the COVID-19 pandemic.\nThe selloff was cut about 207 points off the Dow\'s price, as the Dow fell 232.79 points, or 0.7%, while the S&P 500 gained 0.1%.\nThe selloff comes ...
#  GraphDocument(nodes=[Node(id='Maliek Collins', type='Person', properties={'description': 'Defensive player for the Houston Texans, signed a two-year deal worth $23 million with $20 million guaranteed.'}), Node(id='Houston Texans', type='Organization', properties={'description': 'NFL team that signed Maliek Collins to a two-year deal.'}), Node(id='Nick Caserio', type='Person', properties={'description': 'General Manager of the Houston Texans.'}), Node(id='Andrew Brown', type='Person', properties={'description': 'Director of football administration for the Houston Texans.'}), Node(id='Drew Rosenhaus', type='Person', properties={'description': 'Agent for Maliek Collins.'}), Node(id='Ryan Matha', type='Person', properties={'description': 'Agent for Maliek Collins.'}), Node(id='J.J. Watt', type='Person', properties={'description': 'Former NFL player who has yet to file his retirement papers with the NFL.'}), Node(id='Nfl', type='Organization', properties={'description': 'National Football League.'}), Node(id='Adam Schefter', type='Person', properties={'description': "ESPN reporter who reported on Maliek Collins' contract extension."}), Node(id='Demeco Ryans', type='Person', properties={'description': 'Expected to implement a 4-3 alignment for the Houston Texans.'}), Node(id='Sam Robison', type='Person', properties={'description': "Reporter for Pro Football Talk who commented on Maliek Collins' role."}), Node(id='Cbs Sports', type='Organization', properties={'description': "Reported on J.J. Watt's retirement status."}), Node(id='Dexter Lawrence', type='Person', properties={'description': 'Defensive tackle who recently landed a new deal.'}), Node(id='Daron Payne', type='Person', properties={'description': 'Defensive tackle who recently landed a new deal.'}), Node(id='Jeffery Simmons', type='Person', properties={'description': 'Defensive tackle who recently landed a new deal.'}), Node(id='Ed Oliver', type='Person', properties={'description': 'Defensive tackle who recently landed a new deal.'}), Node(id='Chris Jones', type='Person', properties={'description': 'Defensive tackle for the Kansas City Chiefs, yet to come to terms on a new contract.'}), Node(id='Kansas City Chiefs', type='Organization', properties={'description': 'NFL team with player Chris Jones yet to come to terms on a new contract.'}), Node(id='Quinnen Williams', type='Person', properties={'description': 'Defensive tackle for the New York Jets, yet to come to terms on a new contract.'}), Node(id='New York Jets', type='Organization', properties={'description': 'NFL team with player Quinnen Williams yet to come to terms on a new contract.'})], relationships=[Relationship(source=Node(id='Maliek Collins', type='Person'), target=Node(id='Houston Texans', type='Organization'), type='SIGNED', properties={'description': 'Signed a two-year deal worth $23 million with $20 million guaranteed.'}), Relationship(source=Node(id='Nick Caserio', type='Person'), target=Node(id='Maliek Collins', type='Person'), type='NEGOTIATED', properties={'description': 'Negotiated the deal for the Houston Texans.'}), Relationship(source=Node(id='Andrew Brown', type='Person'), target=Node(id='Maliek Collins', type='Person'), type='NEGOTIATED', properties={'description': 'Negotiated the deal for the Houston Texans.'}), Relationship(source=Node(id='Drew Rosenhaus', type='Person'), target=Node(id='Maliek Collins', type='Person'), type='REPRESENTS', properties={'description': 'Agent for Maliek Collins.'}), Relationship(source=Node(id='Ryan Matha', type='Person'), target=Node(id='Maliek Collins', type='Person'), type='REPRESENTS', properties={'description': 'Agent for Maliek Collins.'}), Relationship(source=Node(id='J.J. Watt', type='Person'), target=Node(id='Nfl', type='Organization'), type='RETIRED_FROM', properties={'description': 'Has yet to file his retirement papers with the NFL.'}), Relationship(source=Node(id='Adam Schefter', type='Person'), target=Node(id='Maliek Collins', type='Person'), type='REP ...
#  GraphDocument(nodes=[Node(id='Patriots', type='Team'), Node(id='Deandre Hopkins', type='Person'), Node(id='Arizona Cardinals', type='Team'), Node(id='New England', type='Location'), Node(id='Foxboro, Mass.', type='Location'), Node(id='Bill Belichick', type='Person'), Node(id='Mac Jones', type='Person'), Node(id='Matthew Judon', type='Person'), Node(id='Titans', type='Team'), Node(id='Nashville', type='Location'), Node(id='Jeremy Fowler', type='Person')], relationships=[Relationship(source=Node(id='Patriots', type='Team'), target=Node(id='Deandre Hopkins', type='Person'), type='COURTED', properties={'description': 'The Patriots courted DeAndre Hopkins once he became a free agent.'}), Relationship(source=Node(id='Deandre Hopkins', type='Person'), target=Node(id='Arizona Cardinals', type='Team'), type='RELEASED_BY', properties={'description': 'DeAndre Hopkins was released by the Arizona Cardinals on May 26.'}), Relationship(source=Node(id='New England', type='Location'), target=Node(id='Deandre Hopkins', type='Person'), type='VISIT', properties={'description': 'DeAndre Hopkins visited New England as a free agent.'}), Relationship(source=Node(id='Foxboro, Mass.', type='Location'), target=Node(id='Deandre Hopkins', type='Person'), type='VISIT', properties={'description': "DeAndre Hopkins' visit to New England started in Foxboro, Mass. and carried into Thursday morning."}), Relationship(source=Node(id='Bill Belichick', type='Person'), target=Node(id='Deandre Hopkins', type='Person'), type='MEETING', properties={'description': 'DeAndre Hopkins met with Bill Belichick during his visit to New England.'}), Relationship(source=Node(id='Patriots', type='Team'), target=Node(id='Deandre Hopkins', type='Person'), type='INTEREST', properties={'description': 'The Patriots expressed interest in DeAndre Hopkins from the beginning when he became a free agent.'}), Relationship(source=Node(id='Mac Jones', type='Person'), target=Node(id='Deandre Hopkins', type='Person'), type='CO-SIGN', properties={'description': 'Mac Jones co-signed DeAndre Hopkins.'}), Relationship(source=Node(id='Matthew Judon', type='Person'), target=Node(id='Deandre Hopkins', type='Person'), type='CO-SIGN', properties={'description': 'Matthew Judon co-signed DeAndre Hopkins.'}), Relationship(source=Node(id='Titans', type='Team'), target=Node(id='Deandre Hopkins', type='Person'), type='MEETING', properties={'description': 'DeAndre Hopkins met with the Titans in Nashville before his trip to New England.'}), Relationship(source=Node(id='Nashville', type='Location'), target=Node(id='Deandre Hopkins', type='Person'), type='VISIT', properties={'description': 'DeAndre Hopkins visited Nashville to meet with the Titans.'}), Relationship(source=Node(id='Jeremy Fowler', type='Person'), target=Node(id='Deandre Hopkins', type='Person'), type='REPORTED', properties={'description': "Jeremy Fowler reported on DeAndre Hopkins' visit to New England."})], source=Document(page_content='The Patriots apparently didn’t waste any time courting DeAndre Hopkins once he hit the open market.\nHopkins officially became an NFL free agent when he was released by the Arizona Cardinals on May 26. Around that juncture, New England reportedly reached out to the star wide receiver’s team to express interest. Those conversations birthed a free-agent visit, which reportedly started Wednesday in Foxboro, Mass. and carried into Thursday morning.\n“I just got official word: DeAndre Hopkins is in New England,” NFL insider Jeremy Fowler said Thursday on ESPN’s “Get Up.” “He’s meeting with the Patriots. He will meet with the coaches, Bill Belichick. The Patriots’ interest remains high. They made that clear with Hopkins’ representatives from the very beginning when he became a free agent. So, we’ll see if they can close on this thing.”\nHopkins has received co-signs from New England team leaders like Mac Jones and Matthew Judon, and the Patriots reportedly are optimistic they can add the five-time Pro Bowl selection. But ...
# ...
#  GraphDocument(nodes=[Node(id='Gordon Mcqueen', type='Person', properties={'description': 'A defender who played for Manchester United, Leeds, and Scotland’s national team. He was diagnosed with vascular dementia in 2021 and died at the age of 70.'}), Node(id='Manchester United', type='Organization', properties={'description': 'A football club based in Manchester, England.'}), Node(id='Leeds', type='Organization', properties={'description': 'A football club based in Leeds, England.'}), Node(id='Scotland National Team', type='Organization', properties={'description': 'The national football team of Scotland.'}), Node(id='St. Mirren', type='Organization', properties={'description': 'A Scottish football club.'}), Node(id='Airdrieonians', type='Organization', properties={'description': 'A Scottish football club.'}), Node(id='Middlesbrough', type='Organization', properties={'description': 'An English football club.'}), Node(id='Bryan Robson', type='Person', properties={'description': 'A former teammate of Gordon McQueen at Manchester United.'})], relationships=[Relationship(source=Node(id='Gordon Mcqueen', type='Person'), target=Node(id='Manchester United', type='Organization'), type='PLAYED_FOR'), Relationship(source=Node(id='Gordon Mcqueen', type='Person'), target=Node(id='Leeds', type='Organization'), type='PLAYED_FOR'), Relationship(source=Node(id='Gordon Mcqueen', type='Person'), target=Node(id='Scotland National Team', type='Organization'), type='PLAYED_FOR'), Relationship(source=Node(id='Gordon Mcqueen', type='Person'), target=Node(id='St. Mirren', type='Organization'), type='PLAYED_FOR'), Relationship(source=Node(id='Gordon Mcqueen', type='Person'), target=Node(id='Airdrieonians', type='Organization'), type='MANAGED'), Relationship(source=Node(id='Gordon Mcqueen', type='Person'), target=Node(id='St. Mirren', type='Organization'), type='COACHED'), Relationship(source=Node(id='Gordon Mcqueen', type='Person'), target=Node(id='Middlesbrough', type='Organization'), type='COACHED'), Relationship(source=Node(id='Bryan Robson', type='Person'), target=Node(id='Manchester United', type='Organization'), type='PLAYED_FOR')], source=Document(page_content='MANCHESTER, England — Gordon McQueen, a defender who played for Manchester United, Leeds and Scotland’s national team, has died. He was 70.\nMcQueen’s death was announced Thursday via a statement from his family released by Man United.\nMcQueen was diagnosed with vascular dementia in 2021.\n“We hope that as-well as creating many great football memories he’ll be remembered most for his character,” his family said. “Our house was always full of friends, family & football just as it was in his last few months as he fought so bravely in what became a very cruel battle against dementia.\n“The disease may have taken him too soon but he definitely lived life to the full, the ultimate entertainer, the absolute heart and soul of every occasion, the most fun dad anyone could wish for.”\nMcQueen began his career at Scottish club St. Mirren and went on to play in England. He was Britain’s most expensive player when he joined Man United for 495,000 pounds (now $626,000).\nAdvertisement\nHe won the English league title with Leeds and the FA Cup with Man United. He also made 30 international appearances for Scotland.\nAfter his playing career, McQueen briefly managed Scottish team Airdrieonians and coached St. Mirren and Middlesbrough.\nUnited said McQueen “oozed command and charisma” at the heart of its defense.\n“Everyone at Manchester United is heartbroken by the loss of our beloved former defender, Gordon McQueen,” the club wrote on Twitter. “Our love and condolences are with his family at this terribly sad time.”\nLeeds also said it was “saddened” to learn of his passing.\n“Gordon was one of the best center backs I had the privilege of playing with,” former Man United teammate Bryan Robson said. “He was a perfect fit for Manchester United with his flair, courage and big personality, and that’s wh ...
#  GraphDocument(nodes=[Node(id='Ge Vernova', type='Organization'), Node(id='Amplus Solar', type='Organization'), Node(id='108 Mw Wind Power Project', type='Project'), Node(id='Tamil Nadu', type='Location'), Node(id='Deepak Maloo', type='Person'), Node(id='Asia Pacific', type='Location'), Node(id='Sharad Pungalia', type='Person'), Node(id='Petronas', type='Organization'), Node(id='2.7-132 Onshore Wind Turbines', type='Product'), Node(id='Bengaluru', type='Location'), Node(id='Pune', type='Location'), Node(id='Vadodara', type='Location'), Node(id='Lm Wind Power', type='Organization')], relationships=[Relationship(source=Node(id='Ge Vernova', type='Organization'), target=Node(id='Amplus Solar', type='Organization'), type='PARTNER'), Relationship(source=Node(id='Ge Vernova', type='Organization'), target=Node(id='108 Mw Wind Power Project', type='Project'), type='SUPPLIER'), Relationship(source=Node(id='108 Mw Wind Power Project', type='Project'), target=Node(id='Tamil Nadu', type='Location'), type='LOCATION'), Relationship(source=Node(id='108 Mw Wind Power Project', type='Project'), target=Node(id='August 2024', type='Date'), type='COMMISSION_DATE'), Relationship(source=Node(id='Ge Vernova', type='Organization'), target=Node(id='2.7-132 Onshore Wind Turbines', type='Product'), type='SUPPLIER'), Relationship(source=Node(id='Ge Vernova', type='Organization'), target=Node(id='India', type='Location'), type='MARKET'), Relationship(source=Node(id='Ge Vernova', type='Organization'), target=Node(id='3 Gw Of Orders', type='Metric'), type='ACHIEVEMENT'), Relationship(source=Node(id='Ge Vernova', type='Organization'), target=Node(id='5 Gw Of Onshore Wind Installed Base', type='Metric'), type='GOAL'), Relationship(source=Node(id='Deepak Maloo', type='Person'), target=Node(id='Ge Vernova', type='Organization'), type='ROLE', properties={'description': 'Regional Sales Leader for GE Vernova’s onshore wind business in Asia Pacific'}), Relationship(source=Node(id='Amplus Solar', type='Organization'), target=Node(id='Sharad Pungalia', type='Person'), type='CEO'), Relationship(source=Node(id='Amplus Solar', type='Organization'), target=Node(id='Petronas', type='Organization'), type='LEADERSHIP'), Relationship(source=Node(id='2.7-132 Onshore Wind Turbines', type='Product'), target=Node(id='India', type='Location'), type='MARKET'), Relationship(source=Node(id='Ge Vernova', type='Organization'), target=Node(id='Bengaluru', type='Location'), type='DESIGN_CENTRE'), Relationship(source=Node(id='Ge Vernova', type='Organization'), target=Node(id='Pune', type='Location'), type='MANUFACTURING_FACILITY'), Relationship(source=Node(id='Lm Wind Power', type='Organization'), target=Node(id='Vadodara', type='Location'), type='MANUFACTURING_FACILITY')], source=Document(page_content='GE Vernova on Thursday said that it has been selected by Amplus Solar for its 108 megawatt (MW) wind power project to be installed in Tamil Nadu, which is expected to be commissioned by August next year.\n“GE Vernova will supply and commission 40 units of its 2.7-132 onshore wind turbines for this 108 MW wind power project. With this order, GE recorded more than 3 GW of orders in India with its 2.7 MW turbine and anticipates crossing 5 GW of onshore wind installed base in the country by early 2024.” the company said.\nAmplus Solar’s wind farm will be commissioned by August 2024 and will provide accessible, affordable, and reliable green energy to local businesses and consumers, it added.\nDeepak Maloo, Regional Sales Leader for GE Vernova’s onshore wind business in Asia Pacific said, “GE has demonstrated expertise in India, having installed over 50 per cent of new wind capacity in the country last year. We are thankful to Amplus Solar for entrusting us with their first wind farm and look forward to furthering our partnership as the company continues to build its renewable energy portfolio under the leadership of Petronas.”\nAmplus Solar CEO, Sharad Pungalia, said, “We are happy to have fo ...
#  GraphDocument(nodes=[Node(id='Flipkart', type='Organization'), Node(id='Polygon Labs', type='Organization'), Node(id='Hang', type='Organization'), Node(id='Firedrops 2.0', type='Program', properties={'description': 'A loyalty program that incentivises brand loyalty through gamification, involving the community and using NFT technology for rewards.'}), Node(id='Naren Ravula', type='Person', properties={'description': 'VP, Head of Product Strategy and Deployment at Flipkart'}), Node(id='Matt Smolin', type='Person', properties={'description': 'CEO and founder of Hang'}), Node(id='Nft', type='Technology', properties={'description': 'Enables easy ownership and redemption of rewards, creating new revenue streams for brands and empowering customers to participate in the loyalty ecosystem.'}), Node(id='Web3', type='Technology', properties={'description': 'Emerging space for loyalty programs, revolutionising brand marketing, storytelling, and customer engagement.'})], relationships=[Relationship(source=Node(id='Flipkart', type='Organization'), target=Node(id='Polygon Labs', type='Organization'), type='PARTNER'), Relationship(source=Node(id='Flipkart', type='Organization'), target=Node(id='Hang', type='Organization'), type='PARTNER'), Relationship(source=Node(id='Flipkart', type='Organization'), target=Node(id='Firedrops 2.0', type='Program'), type='LAUNCH'), Relationship(source=Node(id='Firedrops 2.0', type='Program'), target=Node(id='Nft', type='Technology'), type='USE'), Relationship(source=Node(id='Firedrops 2.0', type='Program'), target=Node(id='Web3', type='Technology'), type='USE'), Relationship(source=Node(id='Naren Ravula', type='Person'), target=Node(id='Flipkart', type='Organization'), type='EMPLOYEE'), Relationship(source=Node(id='Matt Smolin', type='Person'), target=Node(id='Hang', type='Organization'), type='FOUNDER')], source=Document(page_content='E-commerce major Flipkart is partnering with Web3 start-up Polygon Labs and loyalty platform Hang to launch a loyalty program FireDrops 2.0, which incentivises brand loyalty through gamification.\nFireDrops will involve the community and use underlying NFT technology for rewards for a better user experience. NFTs enable easy ownership and redemption of rewards, thereby creating new revenue streams for brands and empowering customers to actively participate in the loyalty ecosystem.\nIt aims to provide an immersive experience to users. Surprises, games and rewards await users as they engage with their favourite brands in meaningful ways, earning exciting benefits and rewards. Quests and games related to their preferred brands allow users to earn membership passes, lifetime discounts and more.\nNaren Ravula, VP, Head of Product Strategy and Deployment at Flipkart, said, “By integrating Web3 and NFTs into brand loyalty programs, we are revolutionising brand marketing, storytelling and customer engagement. We recognise the value of customer loyalty and more importantly, the emerging space of Web3 loyalty. We are excited to partner with one of the best in the space for this innovative brand-first rewards and loyalty program.”\nBrand engagement\nThe program also plans to explore the launch of a dynamic marketplace that allows users to buy and sell rewards, adding flexibility and value to loyalty programs and fostering deeper brand engagement.\n“The world’s most innovative brands, like Flipkart, have a monumental opportunity to redefine how they connect with their customers and build loyalty. The best programs of the future will be gamified, personalised and Web3-enabled. The next generation of loyalty is here, and we are excited to partner with Flipkart to bring it to the masses,” said Matt Smolin, CEO and founder of Hang.')),
#  GraphDocument(nodes=[Node(id='State Street Corporation', type='Organization', properties={'description': 'A financial services and bank holding company'}), Node(id='Nyse:Stt', type='Stock', properties={'description': 'Ticker symbol for State Street Corporation'}), Node(id='Benjamin Graham', type='Person', properties={'description': 'An economist and professional investor'}), Node(id='Market Index Fund', type='Financial_instrument', properties={'description': 'A type of mutual fund designed to follow certain preset rules so that the fund can track a specified basket of underlying investments'}), Node(id='Earnings Per Share (Eps)', type='Financial_metric', properties={'description': "A company's profit divided by the outstanding shares of its common stock"}), Node(id='Revenue', type='Financial_metric', properties={'description': "The total amount of income generated by the sale of goods or services related to the company's primary operations"}), Node(id='Share Price', type='Financial_metric', properties={'description': "The price of a single share of a company's stock"}), Node(id='Dividend', type='Financial_metric', properties={'description': "A distribution of a portion of a company's earnings to its shareholders"}), Node(id='Total Shareholder Return (Tsr)', type='Financial_metric', properties={'description': 'The total return of a stock to an investor, including both capital gains and dividends'})], relationships=[Relationship(source=Node(id='State Street Corporation', type='Organization'), target=Node(id='Nyse:Stt', type='Stock'), type='HAS_TICKER'), Relationship(source=Node(id='State Street Corporation', type='Organization'), target=Node(id='Earnings Per Share (Eps)', type='Financial_metric'), type='HAS_METRIC', properties={'description': 'Improved by 6.1% per year over the last half decade'}), Relationship(source=Node(id='State Street Corporation', type='Organization'), target=Node(id='Revenue', type='Financial_metric'), type='HAS_METRIC', properties={'description': 'Increased by 0.5% over the last half decade'}), Relationship(source=Node(id='State Street Corporation', type='Organization'), target=Node(id='Share Price', type='Financial_metric'), type='HAS_METRIC', properties={'description': 'Decreased by 25% over the last half decade'}), Relationship(source=Node(id='State Street Corporation', type='Organization'), target=Node(id='Total Shareholder Return (Tsr)', type='Financial_metric'), type='HAS_METRIC', properties={'description': 'Increased by 22% over one year'}), Relationship(source=Node(id='State Street Corporation', type='Organization'), target=Node(id='Dividend', type='Financial_metric'), type='HAS_METRIC')], source=Document(page_content="In order to justify the effort of selecting individual stocks, it's worth striving to beat the returns from a market index fund. But even the best stock picker will only win with some selections. So we wouldn't blame long term State Street Corporation (NYSE:STT) shareholders for doubting their decision to hold, with the stock down 25% over a half decade. In contrast, the stock price has popped 9.8% in the last thirty days. However, this may be a matter of broader market optimism, since stocks are up 6.8% in the same time.\nWith that in mind, it's worth seeing if the company's underlying fundamentals have been the driver of long term performance, or if there are some discrepancies.\nView our latest analysis for State Street\nTo paraphrase Benjamin Graham: Over the short term the market is a voting machine, but over the long term it's a weighing machine. One way to examine how market sentiment has changed over time is to look at the interaction between a company's share price and its earnings per share (EPS).\nDuring the unfortunate half decade during which the share price slipped, State Street actually saw its earnings per share (EPS) improve by 6.1% per year. So it doesn't seem like EPS is a great guide to understanding how the market is valuing the stock. Alternatively, growth ex ...

# %%
import time

# time magic doesnt like async
start = time.time()
async_data = await llm_transformer.aconvert_to_graph_documents(documents)
end = time.time()
print(end - start)
# Out:
# 20.44025182723999

# %%
async_data
# Out:
# [GraphDocument(nodes=[Node(id='Jhvephoto', type='Entity'), Node(id='Chevron', type='Company'), Node(id='Nyse:Cvx', type='Stock'), Node(id='Q2 Consensus Earnings Estimates', type='Financial_metric')], relationships=[Relationship(source=Node(id='Chevron', type='Company'), target=Node(id='Nyse:Cvx', type='Stock'), type='HAS'), Relationship(source=Node(id='Chevron', type='Company'), target=Node(id='Q2 Consensus Earnings Estimates', type='Financial_metric'), type='HAS')], source=Document(page_content='JHVEPhoto Like many companies in the O&G sector, the stock of Chevron (NYSE:CVX) has declined about 10% over the past 90-days despite the fact that Q2 consensus earnings estimates have risen sharply (~25%) during that same time frame. Over the years, Chevron has kept a very strong balance sheet. That allowed the...')),
#  GraphDocument(nodes=[Node(id='Firstenergy', type='Organization', properties={'description': 'utilities provider'}), Node(id='Nyse:Fe', type='Stock_ticker'), Node(id='Rtt News', type='Organization')], relationships=[Relationship(source=Node(id='Firstenergy', type='Organization'), target=Node(id='Nyse:Fe', type='Stock_ticker'), type='LISTED_ON'), Relationship(source=Node(id='Firstenergy', type='Organization'), target=Node(id='Rtt News', type='Organization'), type='REPORTED_BY'), Relationship(source=Node(id='Firstenergy', type='Organization'), target=Node(id='Earnings Results', type='Financial_report'), type='POSTED', properties={'description': 'earnings results for the quarter'})], source=Document(page_content='FirstEnergy (NYSE:FE – Get Rating) posted its earnings results on Tuesday. The utilities provider reported $0.53 earnings per share for the quarter, topping the consensus estimate of $0.52 by $0.01, RTT News reports. FirstEnergy had a net margin of 10.85% and a return on equity of 17.17%. During the same period...\nIf the content contained herein violates any of your rights, including those of copyright, you are requested to immediately notify us using via the following email address operanews-external(at)opera.com\nTop News')),
#  GraphDocument(nodes=[Node(id='Dáil', type='Organization'), Node(id='Sinn Féin', type='Organization'), Node(id='John Brady', type='Person'), Node(id='Darragh O’Brien', type='Person'), Node(id='Retained Firefighters', type='Organization'), Node(id='Ireland', type='Location'), Node(id='Pearse Doherty', type='Person'), Node(id='Leinster House', type='Location'), Node(id='Government', type='Organization'), Node(id='Ceann Comhairle Seán Ó Fearghaíl', type='Person'), Node(id='Unions', type='Organization'), Node(id='State’S Industrial Relations Process', type='Concept')], relationships=[Relationship(source=Node(id='John Brady', type='Person'), target=Node(id='Darragh O’Brien', type='Person'), type='ACTION', properties={'description': 'placed an on-call pager in front of Darragh O’Brien during a debate'}), Relationship(source=Node(id='Retained Firefighters', type='Organization'), target=Node(id='Ireland', type='Location'), type='LOCATED_IN'), Relationship(source=Node(id='Retained Firefighters', type='Organization'), target=Node(id='Government', type='Organization'), type='DISPUTE', properties={'description': 'over pay and working conditions'}), Relationship(source=Node(id='Pearse Doherty', type='Person'), target=Node(id='Darragh O’Brien', type='Person'), type='ASKED', properties={'description': 'to make an improved offer in relation to pay for retained firefighters'}), Relationship(source=Node(id='Pearse Doherty', type='Person'), target=Node(id='Darragh O’Brien', type='Person'), type='CHALLENGED', properties={'description': 'to meet with the firefighters'}), Relationship(source=Node(id='John Brady', type='Person'), target=Node(id='Darragh O’Brien', type='Person'), type='ACTION', properties={'description': 'placed the pager on the desk in front of Darragh O’Brien'}), Relationship(source=Node(id='Darragh O’Brien', type='Person'), target=Node(id='John Brady', type='Person'), type='ACCUSED', properties={'description': 'of engaging in an act of theatre'}), Relationship(source=Node(id='Darragh O’Brien', type='Person'), target=Node(id='Retained Firefighters', type='Organization'), type='SUPPORT', properties={'description': 'confident the dispute could be resolved and had immense regard for firefighters'}), Relationship(source=Node(id='Darragh O’Brien', type='Person'), target=Node(id='Unions', type='Organization'), type='ENCOURAGED', properties={'description': 'to re-engage with the State’s industrial relations process'}), Relationship(source=Node(id='Darragh O’Brien', type='Person'), target=Node(id='Sinn Féin', type='Organization'), type='ACCUSED', properties={'description': 'of using the issue for their own political gain'})], source=Document(page_content='The Dáil was almost suspended on Thursday afternoon after Sinn Féin TD John Brady walked across the chamber and placed an on-call pager in front of the Minister for Housing Darragh O’Brien during a debate on retained firefighters.\nMr O’Brien said Mr Brady had taken part in “an act of theatre” that was “obviously choreographed”.\nAround 2,000 retained firefighters around the country staged a second day of industrial action on Tuesday and are due to start all out-strike action from next Tuesday. The mostly part-time workers, who keep the services going outside of Ireland’s larger urban centres, are taking industrial action in a dispute over pay and working conditions.\nSpeaking in the Dáil, Sinn Féin deputy leader Pearse Doherty said firefighters had marched on Leinster House today and were “very angry” at “the fact the Government will not intervene”.\nREAD MORE\nDáil almost suspended after Sinn Féin TD put pager in front of Minister during firefighters debate\nReintroduction of tax relief on mortgages needs to be considered, O’Brien says\nMartin withdraws comment after saying People Before Profit would ‘put the jackboot on people’\nTaoiseach ‘propagated fears’ farmers forced to rewet land due to nature restoration law – Cairns\n“An intervention is required now. I’m asking you to make an i ...
#  GraphDocument(nodes=[Node(id='Epic', type='Organization'), Node(id='Metahuman Animator', type='Tool'), Node(id='Iphone', type='Device'), Node(id='Metahuman', type='Character'), Node(id='Unreal Engine', type='Software'), Node(id='Game Developers Conference', type='Event'), Node(id='March', type='Date'), Node(id='Developers', type='Group'), Node(id='Gpu Hardware', type='Hardware'), Node(id='Live Link Face Ios App', type='Software'), Node(id='Iphone 12', type='Device'), Node(id='Blue Dot', type='Film'), Node(id='3Lateral', type='Team'), Node(id='Radivoje Bukvić', type='Person'), Node(id='Mika Antić', type='Person'), Node(id='Metahuman Hub', type='Platform'), Node(id='Epic Developer Community', type='Community')], relationships=[Relationship(source=Node(id='Epic', type='Organization'), target=Node(id='Metahuman Animator', type='Tool'), type='RELEASED', properties={'description': 'Epic is releasing a new tool designed to capture an actor’s facial performance using a device as simple as an iPhone and apply it to a hyperrealistic “MetaHuman” in the Unreal Engine in “minutes.”'}), Relationship(source=Node(id='Metahuman Animator', type='Tool'), target=Node(id='Game Developers Conference', type='Event'), type='DETAILED_AT', properties={'description': 'The feature, dubbed MetaHuman Animator, was detailed at the Game Developers Conference in March.'}), Relationship(source=Node(id='Epic', type='Organization'), target=Node(id='Developers', type='Group'), type='AVAILABLE_TO', properties={'description': 'MetaHuman Animator is now available for developers to try out for themselves.'}), Relationship(source=Node(id='Epic', type='Organization'), target=Node(id='Blue Dot', type='Film'), type='RELEASED', properties={'description': 'Epic has also released a new video today produced by one of its internal teams to show what the tool is capable of.'}), Relationship(source=Node(id='Metahuman Animator', type='Tool'), target=Node(id='Gpu Hardware', type='Hardware'), type='USES', properties={'description': 'The animation is produced locally using GPU hardware, with the final animation available in minutes.'}), Relationship(source=Node(id='Metahuman Animator', type='Tool'), target=Node(id='Metahuman', type='Character'), type='APPLIES_TO', properties={'description': 'Facial animation can be applied to a MetaHuman character “in just a few clicks.”'}), Relationship(source=Node(id='Metahuman Animator', type='Tool'), target=Node(id='Iphone', type='Device'), type='USES', properties={'description': 'Epic’s MetaHuman Animator can also be used with existing vertical stereo head-mounted camera systems to achieve even greater fidelity.'}), Relationship(source=Node(id='Metahuman Animator', type='Tool'), target=Node(id='Live Link Face Ios App', type='Software'), type='COMBINED_WITH', properties={'description': 'Performance capture using iPhones has been possible in the Unreal Engine since at least 2020 with the launch of Epic’s Live Link Face iOS app, but now, it’s combined with the high level of detail promised by Epic’s MetaHuman technology.'}), Relationship(source=Node(id='Metahuman Animator', type='Tool'), target=Node(id='Iphone 12', type='Device'), type='USES', properties={'description': 'MetaHuman Animator can also be used with existing vertical stereo head-mounted camera systems to achieve even greater fidelity.'}), Relationship(source=Node(id='Blue Dot', type='Film'), target=Node(id='3Lateral', type='Team'), type='PRODUCED_BY', properties={'description': 'It was produced by Epic Games’ 3Lateral team.'}), Relationship(source=Node(id='Blue Dot', type='Film'), target=Node(id='Radivoje Bukvić', type='Person'), type='STARS', properties={'description': 'Blue Dot stars actor Radivoje Bukvić delivering a monologue based on a poem by Mika Antić.'}), Relationship(source=Node(id='Radivoje Bukvić', type='Person'), target=Node(id='Mika Antić', type='Person'), type='BASED_ON_POEM_BY', properties={'description': 'Blue Dot stars actor Radivoje Bukvić delivering a monologue ba ...
#  GraphDocument(nodes=[Node(id='European Commission', type='Organization'), Node(id='Huawei Technologies Co.', type='Organization'), Node(id='Zte Corp.', type='Organization'), Node(id='European Union', type='Organization'), Node(id='Us', type='Country'), Node(id='China', type='Country'), Node(id='Tiktok Inc.', type='Organization'), Node(id='Thomas Seal', type='Person'), Node(id='Alberto Nardelli', type='Person')], relationships=[Relationship(source=Node(id='European Commission', type='Organization'), target=Node(id='Huawei Technologies Co.', type='Organization'), type='BAN', properties={'description': 'The European Commission is planning to ban equipment from Huawei Technologies Co. from its own internal telecommunications networks.'}), Relationship(source=Node(id='European Commission', type='Organization'), target=Node(id='Zte Corp.', type='Organization'), type='BAN', properties={'description': 'The European Commission is planning to ban equipment from ZTE Corp. from its own internal telecommunications networks.'}), Relationship(source=Node(id='European Union', type='Organization'), target=Node(id='Huawei Technologies Co.', type='Organization'), type='CONSIDER_HIGH_RISK', properties={'description': 'The European Union considers Huawei Technologies Co. a high-risk vendor.'}), Relationship(source=Node(id='European Union', type='Organization'), target=Node(id='Zte Corp.', type='Organization'), type='CONSIDER_HIGH_RISK', properties={'description': 'The European Union considers ZTE Corp. a high-risk vendor.'}), Relationship(source=Node(id='Us', type='Country'), target=Node(id='China', type='Country'), type='DETERIORATED_RELATIONSHIP', properties={'description': 'The relationship between the US and China has deteriorated.'}), Relationship(source=Node(id='European Commission', type='Organization'), target=Node(id='Tiktok Inc.', type='Organization'), type='BAN', properties={'description': 'The European Commission blocked its staff from using TikTok Inc. over security concerns.'}), Relationship(source=Node(id='Thomas Seal', type='Person'), target=Node(id='European Commission', type='Organization'), type='ASSISTED'), Relationship(source=Node(id='Alberto Nardelli', type='Person'), target=Node(id='European Commission', type='Organization'), type='ASSISTED')], source=Document(page_content='The European Commission is planning to ban equipment from Chinese vendors Huawei Technologies Co. and ZTE Corp. from its own internal telecommunications networks, people familiar with the matter said.\nThe ban comes ahead of an anticipated update to the European Union’s guidance on 5G mobile networks within the bloc that’s expected to more forcefully encourage members to phase out equipment from the companies, which it considers high risk, the people said, asking not to be identified because the plan isn’t yet public.\nAs the relationship between the US and its allies and China has deteriorated, countries have blocked Chinese technology from their core telecommunications networks because of spying concerns. The move is similar to the commission’s decision to block its staff from using TikTok Inc. over security concerns related to the social-media app’s data-collection practices.\nRead More: TikTok Banned From EU Commission Phones Amid Security Fears\nIn the EU’s review of the 5G “toolbox,” the commission will say that publicly excluding Huawei and ZTE from national networks is justified and will explicitly call out Huawei and ZTE as high-risk vendors by name for the first time. The majority of countries have yet to ban the two Chinese vendors from their networks.\nRepresentatives for Huawei and ZTE didn’t immediately respond to requests for comment.\n— With assistance by Thomas Seal and Alberto Nardelli')),
#  GraphDocument(nodes=[Node(id='Jude Bellingham', type='Person'), Node(id='Real Madrid', type='Organization'), Node(id='Borussia Dortmund', type='Organization'), Node(id='Jesus Vallejo', type='Person'), Node(id='Zidane', type='Person')], relationships=[Relationship(source=Node(id='Jude Bellingham', type='Person'), target=Node(id='Real Madrid', type='Organization'), type='TRANSFER', properties={'description': 'Jude Bellingham moved to Real Madrid.'}), Relationship(source=Node(id='Jude Bellingham', type='Person'), target=Node(id='Borussia Dortmund', type='Organization'), type='PERMISSION', properties={'description': 'Jude Bellingham was given permission by Borussia Dortmund to speak with Real Madrid.'}), Relationship(source=Node(id='Jude Bellingham', type='Person'), target=Node(id='Jesus Vallejo', type='Person'), type='THANKS', properties={'description': 'Jude Bellingham thanked Jesus Vallejo for letting him wear the No.5 shirt.'}), Relationship(source=Node(id='Jude Bellingham', type='Person'), target=Node(id='Zidane', type='Person'), type='ADMIRE', properties={'description': 'Jude Bellingham admires Zidane and his legacy at Real Madrid.'})], source=Document(page_content='Jude Bellingham has also insisted his move to Real Madrid had nothing to do with money, as he explained how his transfer was wrapped up so quickly.\n“Money is not a thing for me,” he said.\n“I dont think about money at all when I make these kinds of decisions. I never have and I never will. I play the game purely out of love.\n“I spoke with people from Real Madrid when I was given permission by Borussia Dortmund and I love the feeling I got from the club. I couldn’t hide it. I told them straight away what I felt and after that happened on Monday it all happened quickly.”\nHe also opened up on how he was given the No.5 shirt, which was worn by defender Jesus Vallejo last season, and what it means to him to have Zidane’s old number on his back.\n“For a start I’d like to thank Jesus Vallejo for letting me wear the No.5,” he explained.\n“I contacted him just to see if it was OK with him and he was just a brilliant guy, he let me wear it and was just so nice about it, so I’m very grateful to him.\n“I’ve said in many interviews how much I admire Zidane, the legacy he has at the club and the legacy of his number.\n“I’m not trying to be the same as him, I’m just trying to be Jude, but it’s definitely a bit of a homage to how great he was.\n“As for the 22, it’s a number that has a lot of meaning to me and in my heart I’m still a 22, I’m just wearing the No.5 on my back.\n“We’ll see what happens in the future, but right now I’m really happy to be given this honour of wearing this number.”')),
#  GraphDocument(nodes=[Node(id='Ryanair', type='Organization'), Node(id='Aidan Murray', type='Person'), Node(id='Darrell Hughes', type='Person'), Node(id='The Independent', type='Organization'), Node(id='The Financial Times', type='Organization'), Node(id='Bbc', type='Organization'), Node(id='Royal Aeronautical Society', type='Organization'), Node(id='Sexual Harassment', type='Concept')], relationships=[Relationship(source=Node(id='Ryanair', type='Organization'), target=Node(id='Aidan Murray', type='Person'), type='EMPLOYED', properties={'description': 'Chief Pilot, appointed in 2020, with the airline for 28 years'}), Relationship(source=Node(id='Ryanair', type='Organization'), target=Node(id='Aidan Murray', type='Person'), type='TERMINATED', properties={'description': 'Terminated for repeated inappropriate and unacceptable behaviour towards female pilots'}), Relationship(source=Node(id='Aidan Murray', type='Person'), target=Node(id='Sexual Harassment', type='Concept'), type='ACCUSED_OF', properties={'description': 'Allegedly harassed nine junior colleagues, including sending inappropriate text messages and altering flight rosters'}), Relationship(source=Node(id='Ryanair', type='Organization'), target=Node(id='Darrell Hughes', type='Person'), type='EMPLOYED', properties={'description': 'Chief People Officer'}), Relationship(source=Node(id='Darrell Hughes', type='Person'), target=Node(id='Aidan Murray', type='Person'), type='TERMINATED', properties={'description': 'Terminated with immediate effect for breach of anti-harassment policy'}), Relationship(source=Node(id='The Independent', type='Organization'), target=Node(id='Aidan Murray', type='Person'), type='REPORTED', properties={'description': 'Reported on allegations of harassment'}), Relationship(source=Node(id='The Financial Times', type='Organization'), target=Node(id='Aidan Murray', type='Person'), type='REPORTED', properties={'description': 'Reported that Mr. Murray has seven days to appeal against dismissal'}), Relationship(source=Node(id='Bbc', type='Organization'), target=Node(id='Aidan Murray', type='Person'), type='REPORTED', properties={'description': 'Attempted to contact Mr. Murray for comment'}), Relationship(source=Node(id='Royal Aeronautical Society', type='Organization'), target=Node(id='Sexual Harassment', type='Concept'), type='REPORTED', properties={'description': 'Reported on sexism and sexual harassment in airline pilot training'})], source=Document(page_content='Reuters\nRyanair has sacked its chief pilot after an investigation into his alleged sexual harassment of female colleagues.\nThe airline told staff that he had been fired for "a pattern of repeated inappropriate and unacceptable behaviour towards a number of female pilots".\nThe chief pilot, named in reports as Aidan Murray was appointed in 2020 and had been with the airline for 28 years.\nRyanair declined to comment "on queries relating to individual employees".\nAccording to The Independent, Mr Murray allegedly harassed nine junior colleagues, including sending text messages to some with comments on their bodies.\nMr Murray, 58, is also accused of altering flight rosters to fly with certain female pilots.\nIn a note to staff, Ryanair\'s chief people officer, Darrell Hughes, said Mr Murray\'s employment had been "terminated with immediate effect".\nAn investigation found his behaviour "was in breach of our anti-harassment policy". Ryanair said staff should be able to come to work "in a safe and secure environment".\n"We would ask all of you to respect the privacy and integrity of those brave individuals who came forward to assist us in this investigation," Mr Hughes added.\nThe Financial Times reported that Mr Murray has seven days to launch an appeal against his dismissal.\nThe BBC has attempted to contact Mr Murray for comment.\nThe job of chief pilot is an important one. The holder is both a highly qualified airline captain and a manager, responsible for overseeing other pilots based at a hub ...
#  GraphDocument(nodes=[Node(id='Keybank', type='Organization', properties={'description': "One of the nation's largest bank-based financial services companies, headquartered in Cleveland, Ohio."}), Node(id='American Fork Branch', type='Place', properties={'description': "KeyBank's first new branch in the Western half of the U.S. in more than a decade, located at 717 West Main in American Fork."}), Node(id='Drew Yergensen', type='Person', properties={'description': 'KeyBank Utah market president and commercial banking leader.'}), Node(id='Jason Scorup', type='Person', properties={'description': 'KeyBank American Fork branch manager.'}), Node(id='Five.12 Foundation', type='Organization', properties={'description': 'Based in Alpine, Utah, organizes and distributes weekend food bags to students in need at four American Fork elementary schools.'}), Node(id='Laura Suter', type='Person', properties={'description': 'Regional Communications Manager at KeyBank.'}), Node(id='Keycorp', type='Organization', properties={'description': 'Parent company of KeyBank, headquartered in Cleveland, Ohio.'}), Node(id='American Fork Chamber Of Commerce', type='Organization')], relationships=[Relationship(source=Node(id='Keybank', type='Organization'), target=Node(id='American Fork Branch', type='Place'), type='HAS_BRANCH'), Relationship(source=Node(id='Keybank', type='Organization'), target=Node(id='Drew Yergensen', type='Person'), type='EMPLOYS'), Relationship(source=Node(id='Keybank', type='Organization'), target=Node(id='Jason Scorup', type='Person'), type='EMPLOYS'), Relationship(source=Node(id='American Fork Branch', type='Place'), target=Node(id='Five.12 Foundation', type='Organization'), type='DONATED_TO', properties={'description': '$10,000 donation.'}), Relationship(source=Node(id='American Fork Branch', type='Place'), target=Node(id='American Fork Chamber Of Commerce', type='Organization'), type='COLLABORATES_WITH'), Relationship(source=Node(id='Laura Suter', type='Person'), target=Node(id='Keybank', type='Organization'), type='WORKS_FOR'), Relationship(source=Node(id='Keycorp', type='Organization'), target=Node(id='Keybank', type='Organization'), type='OWNS')], source=Document(page_content='CLEVELAND, UT / ACCESSWIRE / June 15, 2023 / KeyBank recently commemorated the one-year anniversary of its American Fork branch - the company\'s first new branch in the Western half of the U.S. in more than a decade. The celebration included a networking event with the branch\'s business clients and the American Fork Chamber of Commerce, as well as a $10,000 donation to the Five.12 Foundation.\n"We\'ve had a great first year in American Fork," said Drew Yergensen, KeyBank Utah market president and commercial banking leader. "We have really enjoyed meeting and working more closely with our new neighbors, clients and community partners, and we look forward to strengthening those relationships even further in the coming years."\nThe American Fork branch highlights KeyBank\'s state-of-the-art financial wellness center model, which is staffed with financial wellness consultants rather than a traditional teller line. All transactions are completed at desks, where consultants also conduct comprehensive financial wellness reviews and discussions. Clients can also meet with specialists in mortgage, investments, business banking and more at the location.\nThe branch features digital video screens and a client hospitality space that also serves as an area for financial seminars and group presentations with clients and the public, as well as a drive-up teller line, ATM and complimentary parking. In addition to helping individuals and families achieve their financial goals, the branch also serves clients seeking to develop and grow businesses in the area.\n"We are here to help the community of American Fork with all of their banking and small business needs," said Jason Scorup, KeyBank American Fork branch manager. "We also take pride in the positive impact we\'ve had ...
#  GraphDocument(nodes=[Node(id='Vivo X90S', type='Product', properties={'description': 'A new smartphone teased by Jia Jingdong, featuring a Zeiss-tuned triple rear camera unit and expected to run on MediaTek Dimensity 9200+ SoC.'}), Node(id='Jia Jingdong', type='Person', properties={'description': "Vivo's Vice President and General Manager of Product Strategy."}), Node(id='Vivo', type='Organization', properties={'description': 'A smartphone manufacturer.'}), Node(id='Weibo', type='Platform', properties={'description': 'A Chinese microblogging platform.'}), Node(id='Vivo X90', type='Product', properties={'description': 'A smartphone in the Vivo X90 series, featuring MediaTek Dimensity 9200 SoC and Wi-Fi 6 connectivity.'}), Node(id='Vivo X90 Pro', type='Product', properties={'description': 'A smartphone in the Vivo X90 series, recently debuted in India.'}), Node(id='Mediatek Dimensity 9200+ Soc', type='Technology', properties={'description': 'A system on chip expected to power the Vivo X90s.'}), Node(id='Mediatek Dimensity 9200 Soc', type='Technology', properties={'description': 'A system on chip found on the Vivo X90.'}), Node(id='Zeiss', type='Organization', properties={'description': 'A company known for its camera lens technology.'}), Node(id='Tenaa', type='Organization', properties={'description': 'A Chinese regulatory body that lists specifications of electronic devices.'})], relationships=[Relationship(source=Node(id='Jia Jingdong', type='Person'), target=Node(id='Vivo', type='Organization'), type='AFFILIATION', properties={'description': 'Vice President and General Manager of Product Strategy.'}), Relationship(source=Node(id='Jia Jingdong', type='Person'), target=Node(id='Weibo', type='Platform'), type='POSTED_ON', properties={'description': 'Teased the Vivo X90s on Thursday.'}), Relationship(source=Node(id='Vivo X90S', type='Product'), target=Node(id='Vivo X90', type='Product'), type='SIMILAR_TO', properties={'description': 'Has a design similar to Vivo X90.'}), Relationship(source=Node(id='Vivo X90S', type='Product'), target=Node(id='Vivo X90 Pro', type='Product'), type='SIMILAR_TO', properties={'description': 'Has a design similar to Vivo X90 Pro.'}), Relationship(source=Node(id='Vivo X90S', type='Product'), target=Node(id='Mediatek Dimensity 9200+ Soc', type='Technology'), type='POWERED_BY', properties={'description': 'Expected to run on MediaTek Dimensity 9200+ SoC.'}), Relationship(source=Node(id='Vivo X90', type='Product'), target=Node(id='Mediatek Dimensity 9200 Soc', type='Technology'), type='POWERED_BY', properties={'description': 'Runs on MediaTek Dimensity 9200 SoC.'}), Relationship(source=Node(id='Vivo X90S', type='Product'), target=Node(id='Zeiss', type='Organization'), type='FEATURES', properties={'description': 'Has a Zeiss-tuned triple rear camera unit.'}), Relationship(source=Node(id='Vivo X90S', type='Product'), target=Node(id='Tenaa', type='Organization'), type='LISTED_BY', properties={'description': 'Listed by TENAA in May with specifications.'})], source=Document(page_content="Vivo X90s has been teased by Jia Jingdong, Vivo's Vice President and General Manager of Product Strategy via Weibo on Thursday. The new smartphone has a design similar to its Vivo X90 series siblings — Vivo X90 and Vivo X90 Pro. The Vivo X90s is shown to have a Zeiss-tuned triple rear camera unit. The upcoming model is expected to retain the key specification of the Vivo X90. Meanwhile, Chinese tipsters have leaked the specifications of the upcoming handset. The Vivo X90s is said to run on MediaTek Dimensity 9200+ SoC and could be offered in four different colour options.\nJia Jingdong posted an image of the Vivo X90s on the Chinese microblogging platform providing us a glimpse of the design from the rear. The render shows the handset in a white finish with rounded corners. The image suggests Zeiss branded triple rear cameras on the rear panel along with an LED flash. It seems to have a glass back with the Vivo branding at the ...
#  GraphDocument(nodes=[Node(id='Xpeng', type='Organization'), Node(id='Beijing', type='Location'), Node(id='Tesla', type='Organization')], relationships=[Relationship(source=Node(id='Xpeng', type='Organization'), target=Node(id='Beijing', type='Location'), type='LAUNCHED', properties={'description': 'assisted-driving technology launched in Beijing and three other cities'}), Relationship(source=Node(id='Xpeng', type='Organization'), target=Node(id='Tesla', type='Organization'), type='RIVAL')], source=Document(page_content='Chinese electric-vehicle maker\nXPeng\nsaid Thursday its assisted-driving technology has been launched in Beijing and three other cities. The\nTesla\nrival’s stock was rising in premarket trading.')),
#  GraphDocument(nodes=[Node(id='Bank Of America', type='Organization', properties={'description': "One of the world's leading financial institutions, serving individual consumers, small and middle-market businesses and large corporations with a full range of banking, investing, asset management and other financial and risk management products and services."}), Node(id='Tram Nguyen', type='Person', properties={'description': 'Global Head of Strategic and Sustainable Investments at Bank of America'}), Node(id='Nasir Qadree', type='Person', properties={'description': 'Founder of Zeal and a graduate of a Historically Black College and University (HBCU)'}), Node(id='Zeal', type='Organization', properties={'description': 'Provides overlooked founders with the resources they need to scale towards their next stage of growth'}), Node(id='Esusu', type='Organization', properties={'description': 'One of the few Black-owned unicorns, which provides tools to help immigrants and minorities to provide rent reporting and data solutions for credit building'}), Node(id='Chingona Ventures', type='Organization', properties={'description': 'Led by General Partner Samara Hernandez, targets founders with unique backgrounds creating businesses in markets that are often overlooked'}), Node(id='Samara Hernandez', type='Person', properties={'description': 'General Partner of Chingona Ventures'}), Node(id='Papaya', type='Organization', properties={'description': 'A bilingual STEM tutoring organization to close the educational gap for underserved students'})], relationships=[Relationship(source=Node(id='Bank Of America', type='Organization'), target=Node(id='Tram Nguyen', type='Person'), type='EMPLOYS', properties={'description': 'Global Head of Strategic and Sustainable Investments'}), Relationship(source=Node(id='Nasir Qadree', type='Person'), target=Node(id='Zeal', type='Organization'), type='FOUNDED'), Relationship(source=Node(id='Zeal', type='Organization'), target=Node(id='Esusu', type='Organization'), type='INVESTED_IN'), Relationship(source=Node(id='Chingona Ventures', type='Organization'), target=Node(id='Samara Hernandez', type='Person'), type='LED_BY'), Relationship(source=Node(id='Chingona Ventures', type='Organization'), target=Node(id='Papaya', type='Organization'), type='INVESTED_IN'), Relationship(source=Node(id='Bank Of America', type='Organization'), target=Node(id='Chingona Ventures', type='Organization'), type='INVESTED_IN'), Relationship(source=Node(id='Bank Of America', type='Organization'), target=Node(id='Zeal', type='Organization'), type='INVESTED_IN')], source=Document(page_content='Investments in Diverse-led Funds Result in Capital Deployed to Over 1,000 Companies Across the U.S.\nNEW YORK, June 15, 2023 /PRNewswire/ -- Bank of America today announced that it has committed more than $500 million in equity investments to minority- and women-led funds, more than doubling its initial $200 million commitment.\nThe bank has committed equity to more than 150 funds, which to date have invested in over 1,000 companies that span 40 states. These companies are led by 1,500 diverse entrepreneurs and employ over 21,000 people.\n"We work across our company to address critical needs in our communities, including the lack of access to capital that diverse business owners face as they start or grow their businesses," said Tram Nguyen, Global Head of Strategic and Sustainable Investments at Bank of America. "We want to empower the talented fund managers who keenly understand how to identify and support those business owners. Each time we support a minority- or women-led fund, they in turn support diverse entrepreneurs, which ultimately helps us toward achieving our goal to advance racial equality and economic opportunity."\nNot only are fund managers breaking down barriers themselves, but they are also investing in companies looking to catalyze change. As a graduate of a Historically Black College and University (HBCU), Nasir Qadree founded Zeal t ...
#  GraphDocument(nodes=[Node(id='Unitedhealth Group Inc.', type='Organization', properties={'description': 'Health insurer'}), Node(id='John Rex', type='Person', properties={'description': 'Chief Financial Officer of UnitedHealth Group Inc.'}), Node(id='Goldman Sachs Investor Conference', type='Event'), Node(id='Oppenheimer', type='Organization', properties={'description': 'Analyst firm'}), Node(id='Michael Wiederhorn', type='Person', properties={'description': 'Analyst at Oppenheimer'}), Node(id='Humana Inc.', type='Organization', properties={'description': 'Health insurer with large Medicare Advantage presence'}), Node(id='Centene Corp.', type='Organization', properties={'description': 'Health insurer in Medicare Advantage business'}), Node(id='Elevance Health Inc.', type='Organization', properties={'description': 'Health insurer in Medicare Advantage business'}), Node(id='Cvs Health Corp.', type='Organization', properties={'description': 'Health insurer in Medicare Advantage business'}), Node(id='Dow Jones Industrial Average', type='Index'), Node(id='S&P 500', type='Index'), Node(id='Walgreens Boots Alliance Inc.', type='Organization', properties={'description': 'Lowest priced component of the Dow'}), Node(id='Marketwatch', type='Organization', properties={'description': 'Operated by Dow Jones & Co.'}), Node(id='Dow Jones & Co.', type='Organization'), Node(id='The Wall Street Journal', type='Organization')], relationships=[Relationship(source=Node(id='Unitedhealth Group Inc.', type='Organization'), target=Node(id='Dow Jones Industrial Average', type='Index'), type='COMPONENT', properties={'description': 'Highest-priced component'}), Relationship(source=Node(id='Unitedhealth Group Inc.', type='Organization'), target=Node(id='S&P 500', type='Index'), type='COMPONENT'), Relationship(source=Node(id='Humana Inc.', type='Organization'), target=Node(id='S&P 500', type='Index'), type='COMPONENT'), Relationship(source=Node(id='Centene Corp.', type='Organization'), target=Node(id='S&P 500', type='Index'), type='COMPONENT'), Relationship(source=Node(id='Elevance Health Inc.', type='Organization'), target=Node(id='S&P 500', type='Index'), type='COMPONENT'), Relationship(source=Node(id='Cvs Health Corp.', type='Organization'), target=Node(id='S&P 500', type='Index'), type='COMPONENT'), Relationship(source=Node(id='Walgreens Boots Alliance Inc.', type='Organization'), target=Node(id='Dow Jones Industrial Average', type='Index'), type='COMPONENT', properties={'description': 'Lowest-priced component'}), Relationship(source=Node(id='John Rex', type='Person'), target=Node(id='Goldman Sachs Investor Conference', type='Event'), type='ATTENDED'), Relationship(source=Node(id='Marketwatch', type='Organization'), target=Node(id='Dow Jones & Co.', type='Organization'), type='OPERATED_BY'), Relationship(source=Node(id='Marketwatch', type='Organization'), target=Node(id='The Wall Street Journal', type='Organization'), type='PUBLISHED_INDEPENDENTLY_FROM')], source=Document(page_content='Health insurer\'s stock suffers second-biggest price decline since it starting trading 39 years ago\nShares of UnitedHealth Group Inc. took a dive Wednesday to suffer their worst percentage performance in three years, after the health insurer said it was facing higher costs from pent-up demand for surgeries.\nThe stock (UNH) was by far the biggest decliner within the Dow Jones Industrial Average , and was among the worst performers in the S&P 500 , along with fellow health insurers with Medicare Advantage exposure.\nUnitedHealth\'s stock dropped 6.4% to a one-year closing low of $459.86. That was the biggest percentage decline since it sank 7.2% on June 11, 2020.\nThe stock\'s price decline of $31.45 was the second-biggest since it started trading in October 1984, behind only the $47.00 (17.3%) plunge on March 16, 2020, at the height of the COVID-19 pandemic.\nThe selloff was cut about 207 points off the Dow\'s price, as the Dow fell 232.79 points, or 0.7%, while the S&P ...
#  GraphDocument(nodes=[Node(id='Maliek Collins', type='Person', properties={'description': 'Defensive player for the Houston Texans, signed a two-year deal worth $23 million with $20 million guaranteed.'}), Node(id='Houston Texans', type='Organization', properties={'description': 'NFL team that signed Maliek Collins to a two-year deal.'}), Node(id='Nick Caserio', type='Person', properties={'description': 'General Manager of the Houston Texans.'}), Node(id='Andrew Brown', type='Person', properties={'description': 'Director of football administration for the Houston Texans.'}), Node(id='Drew Rosenhaus', type='Person', properties={'description': 'Agent for Maliek Collins.'}), Node(id='Ryan Matha', type='Person', properties={'description': 'Agent for Maliek Collins.'}), Node(id='Adam Schefter', type='Person', properties={'description': 'ESPN reporter who reported the signing of Maliek Collins.'}), Node(id='J.J. Watt', type='Person', properties={'description': 'NFL player who has yet to file his retirement papers with the NFL.'}), Node(id='Nfl', type='Organization', properties={'description': 'National Football League.'}), Node(id='Dallas Cowboys', type='Organization', properties={'description': 'NFL team where Maliek Collins played from 2016 to 2019.'}), Node(id='Las Vegas Raiders', type='Organization', properties={'description': 'NFL team where Maliek Collins played in 2020.'}), Node(id='Demeco Ryans', type='Person', properties={'description': 'Expected to implement a 4-3 alignment for the Houston Texans.'}), Node(id='Sam Robison', type='Person', properties={'description': "Reporter for Pro Football Talk who commented on Maliek Collins' role."}), Node(id='Dexter Lawrence', type='Person', properties={'description': 'Defensive tackle who recently landed a new deal.'}), Node(id='Daron Payne', type='Person', properties={'description': 'Defensive tackle who recently landed a new deal.'}), Node(id='Jeffery Simmons', type='Person', properties={'description': 'Defensive tackle who recently landed a new deal.'}), Node(id='Ed Oliver', type='Person', properties={'description': 'Defensive tackle who recently landed a new deal.'}), Node(id='Chris Jones', type='Person', properties={'description': 'Defensive tackle for the Kansas City Chiefs, yet to come to terms on a new contract.'}), Node(id='Kansas City Chiefs', type='Organization', properties={'description': 'NFL team where Chris Jones plays.'}), Node(id='Quinnen Williams', type='Person', properties={'description': 'Defensive tackle for the New York Jets, yet to come to terms on a new contract.'}), Node(id='New York Jets', type='Organization', properties={'description': 'NFL team where Quinnen Williams plays.'}), Node(id='Cbs Sports', type='Organization', properties={'description': 'Reported that J.J. Watt has yet to file his retirement papers with the NFL.'})], relationships=[Relationship(source=Node(id='Houston Texans', type='Organization'), target=Node(id='Maliek Collins', type='Person'), type='SIGNED', properties={'description': 'Signed Maliek Collins to a two-year deal worth $23 million with $20 million guaranteed.'}), Relationship(source=Node(id='Nick Caserio', type='Person'), target=Node(id='Maliek Collins', type='Person'), type='NEGOTIATED', properties={'description': 'Negotiated the deal for Maliek Collins.'}), Relationship(source=Node(id='Andrew Brown', type='Person'), target=Node(id='Maliek Collins', type='Person'), type='NEGOTIATED', properties={'description': 'Negotiated the deal for Maliek Collins.'}), Relationship(source=Node(id='Drew Rosenhaus', type='Person'), target=Node(id='Maliek Collins', type='Person'), type='REPRESENTS', properties={'description': 'Agent for Maliek Collins.'}), Relationship(source=Node(id='Ryan Matha', type='Person'), target=Node(id='Maliek Collins', type='Person'), type='REPRESENTS', properties={'description': 'Agent for Maliek Collins.'}), Relationship(source=Node(id='Adam Schefter', type='Person'), target=Node(id='Maliek Collins', type='Person'), ty ...
#  GraphDocument(nodes=[Node(id='Patriots', type='Team'), Node(id='Deandre Hopkins', type='Person'), Node(id='Arizona Cardinals', type='Team'), Node(id='New England', type='Location'), Node(id='Foxboro, Mass.', type='Location'), Node(id='Jeremy Fowler', type='Person'), Node(id='Espn', type='Organization'), Node(id='Bill Belichick', type='Person'), Node(id='Mac Jones', type='Person'), Node(id='Matthew Judon', type='Person'), Node(id='Titans', type='Team'), Node(id='Nashville', type='Location')], relationships=[Relationship(source=Node(id='Patriots', type='Team'), target=Node(id='Deandre Hopkins', type='Person'), type='COURTED', properties={'description': 'The Patriots courted DeAndre Hopkins once he became a free agent.'}), Relationship(source=Node(id='Deandre Hopkins', type='Person'), target=Node(id='Arizona Cardinals', type='Team'), type='RELEASED_BY', properties={'description': 'DeAndre Hopkins was released by the Arizona Cardinals on May 26.'}), Relationship(source=Node(id='Patriots', type='Team'), target=Node(id='Deandre Hopkins', type='Person'), type='EXPRESSED_INTEREST', properties={'description': "New England reportedly reached out to DeAndre Hopkins' team to express interest."}), Relationship(source=Node(id='Deandre Hopkins', type='Person'), target=Node(id='Patriots', type='Team'), type='VISITED', properties={'description': 'DeAndre Hopkins visited the Patriots starting Wednesday in Foxboro, Mass. and carried into Thursday morning.'}), Relationship(source=Node(id='Jeremy Fowler', type='Person'), target=Node(id='Espn', type='Organization'), type='WORKS_FOR', properties={'description': 'Jeremy Fowler is an NFL insider for ESPN.'}), Relationship(source=Node(id='Deandre Hopkins', type='Person'), target=Node(id='Patriots', type='Team'), type='MEETING_WITH', properties={'description': 'DeAndre Hopkins is meeting with the Patriots.'}), Relationship(source=Node(id='Deandre Hopkins', type='Person'), target=Node(id='Bill Belichick', type='Person'), type='MEETING_WITH', properties={'description': 'DeAndre Hopkins will meet with Bill Belichick.'}), Relationship(source=Node(id='Patriots', type='Team'), target=Node(id='Deandre Hopkins', type='Person'), type='INTEREST', properties={'description': "The Patriots' interest in DeAndre Hopkins remains high."}), Relationship(source=Node(id='Mac Jones', type='Person'), target=Node(id='Deandre Hopkins', type='Person'), type='CO-SIGNED', properties={'description': 'Mac Jones co-signed DeAndre Hopkins.'}), Relationship(source=Node(id='Matthew Judon', type='Person'), target=Node(id='Deandre Hopkins', type='Person'), type='CO-SIGNED', properties={'description': 'Matthew Judon co-signed DeAndre Hopkins.'}), Relationship(source=Node(id='Deandre Hopkins', type='Person'), target=Node(id='Patriots', type='Team'), type='POTENTIAL_DEAL', properties={'description': 'The Patriots are optimistic they can add DeAndre Hopkins.'}), Relationship(source=Node(id='Deandre Hopkins', type='Person'), target=Node(id='Titans', type='Team'), type='VISITED', properties={'description': 'DeAndre Hopkins met with the Titans in Nashville.'})], source=Document(page_content='The Patriots apparently didn’t waste any time courting DeAndre Hopkins once he hit the open market.\nHopkins officially became an NFL free agent when he was released by the Arizona Cardinals on May 26. Around that juncture, New England reportedly reached out to the star wide receiver’s team to express interest. Those conversations birthed a free-agent visit, which reportedly started Wednesday in Foxboro, Mass. and carried into Thursday morning.\n“I just got official word: DeAndre Hopkins is in New England,” NFL insider Jeremy Fowler said Thursday on ESPN’s “Get Up.” “He’s meeting with the Patriots. He will meet with the coaches, Bill Belichick. The Patriots’ interest remains high. They made that clear with Hopkins’ representatives from the very beginning when he became a free agent. So, we’ll see if they can close on this thing.”\nHopkins has received co-s ...
# ...
#  GraphDocument(nodes=[Node(id='Gordon Mcqueen', type='Person', properties={'description': 'A defender who played for Manchester United, Leeds, and Scotland’s national team. Diagnosed with vascular dementia in 2021. Died at the age of 70.'}), Node(id='Manchester United', type='Organization', properties={'description': 'A football club based in Manchester, England.'}), Node(id='Leeds', type='Organization', properties={'description': 'A football club based in Leeds, England.'}), Node(id='Scotland’S National Team', type='Organization', properties={'description': 'The national football team of Scotland.'}), Node(id='St. Mirren', type='Organization', properties={'description': 'A Scottish football club.'}), Node(id='Airdrieonians', type='Organization', properties={'description': 'A Scottish football club.'}), Node(id='Middlesbrough', type='Organization', properties={'description': 'An English football club.'}), Node(id='Bryan Robson', type='Person', properties={'description': 'Former Manchester United teammate of Gordon McQueen.'})], relationships=[Relationship(source=Node(id='Gordon Mcqueen', type='Person'), target=Node(id='Manchester United', type='Organization'), type='PLAYED_FOR', properties={'description': 'Gordon McQueen played for Manchester United.'}), Relationship(source=Node(id='Gordon Mcqueen', type='Person'), target=Node(id='Leeds', type='Organization'), type='PLAYED_FOR', properties={'description': 'Gordon McQueen played for Leeds.'}), Relationship(source=Node(id='Gordon Mcqueen', type='Person'), target=Node(id='Scotland’S National Team', type='Organization'), type='PLAYED_FOR', properties={'description': 'Gordon McQueen played for Scotland’s national team.'}), Relationship(source=Node(id='Gordon Mcqueen', type='Person'), target=Node(id='St. Mirren', type='Organization'), type='PLAYED_FOR', properties={'description': 'Gordon McQueen began his career at St. Mirren.'}), Relationship(source=Node(id='Gordon Mcqueen', type='Person'), target=Node(id='Airdrieonians', type='Organization'), type='MANAGED', properties={'description': 'Gordon McQueen briefly managed Airdrieonians.'}), Relationship(source=Node(id='Gordon Mcqueen', type='Person'), target=Node(id='St. Mirren', type='Organization'), type='COACHED', properties={'description': 'Gordon McQueen coached St. Mirren.'}), Relationship(source=Node(id='Gordon Mcqueen', type='Person'), target=Node(id='Middlesbrough', type='Organization'), type='COACHED', properties={'description': 'Gordon McQueen coached Middlesbrough.'}), Relationship(source=Node(id='Bryan Robson', type='Person'), target=Node(id='Gordon Mcqueen', type='Person'), type='TEAMMATE', properties={'description': 'Bryan Robson was a former Manchester United teammate of Gordon McQueen.'})], source=Document(page_content='MANCHESTER, England — Gordon McQueen, a defender who played for Manchester United, Leeds and Scotland’s national team, has died. He was 70.\nMcQueen’s death was announced Thursday via a statement from his family released by Man United.\nMcQueen was diagnosed with vascular dementia in 2021.\n“We hope that as-well as creating many great football memories he’ll be remembered most for his character,” his family said. “Our house was always full of friends, family & football just as it was in his last few months as he fought so bravely in what became a very cruel battle against dementia.\n“The disease may have taken him too soon but he definitely lived life to the full, the ultimate entertainer, the absolute heart and soul of every occasion, the most fun dad anyone could wish for.”\nMcQueen began his career at Scottish club St. Mirren and went on to play in England. He was Britain’s most expensive player when he joined Man United for 495,000 pounds (now $626,000).\nAdvertisement\nHe won the English league title with Leeds and the FA Cup with Man United. He also made 30 international appearances for Scotland.\nAfter his playing career, McQueen briefly managed Scottish team Airdrieonians and coached St. Mirren a ...
#  GraphDocument(nodes=[Node(id='Ge Vernova', type='Organization'), Node(id='Amplus Solar', type='Organization'), Node(id='108 Mw Wind Power Project', type='Project'), Node(id='Tamil Nadu', type='Location'), Node(id='Deepak Maloo', type='Person'), Node(id='Asia Pacific', type='Location'), Node(id='Sharad Pungalia', type='Person'), Node(id='Petronas', type='Organization'), Node(id='2.7-132 Onshore Wind Turbines', type='Product'), Node(id='Bengaluru', type='Location'), Node(id='Pune', type='Location'), Node(id='Vadodara', type='Location'), Node(id='Lm Wind Power', type='Organization')], relationships=[Relationship(source=Node(id='Ge Vernova', type='Organization'), target=Node(id='Amplus Solar', type='Organization'), type='PARTNER'), Relationship(source=Node(id='Ge Vernova', type='Organization'), target=Node(id='108 Mw Wind Power Project', type='Project'), type='SUPPLIER'), Relationship(source=Node(id='108 Mw Wind Power Project', type='Project'), target=Node(id='Tamil Nadu', type='Location'), type='LOCATION'), Relationship(source=Node(id='108 Mw Wind Power Project', type='Project'), target=Node(id='August 2024', type='Date'), type='COMMISSION_DATE'), Relationship(source=Node(id='Ge Vernova', type='Organization'), target=Node(id='2.7-132 Onshore Wind Turbines', type='Product'), type='SUPPLIER'), Relationship(source=Node(id='Deepak Maloo', type='Person'), target=Node(id='Ge Vernova', type='Organization'), type='EMPLOYEE', properties={'description': 'Regional Sales Leader for GE Vernova’s onshore wind business in Asia Pacific'}), Relationship(source=Node(id='Sharad Pungalia', type='Person'), target=Node(id='Amplus Solar', type='Organization'), type='CEO'), Relationship(source=Node(id='Amplus Solar', type='Organization'), target=Node(id='Petronas', type='Organization'), type='SUBSIDIARY'), Relationship(source=Node(id='Ge Vernova', type='Organization'), target=Node(id='Bengaluru', type='Location'), type='TECHNOLOGY_CENTRE'), Relationship(source=Node(id='Ge Vernova', type='Organization'), target=Node(id='Pune', type='Location'), type='MANUFACTURING_FACILITY'), Relationship(source=Node(id='Lm Wind Power', type='Organization'), target=Node(id='Vadodara', type='Location'), type='MANUFACTURING_FACILITY')], source=Document(page_content='GE Vernova on Thursday said that it has been selected by Amplus Solar for its 108 megawatt (MW) wind power project to be installed in Tamil Nadu, which is expected to be commissioned by August next year.\n“GE Vernova will supply and commission 40 units of its 2.7-132 onshore wind turbines for this 108 MW wind power project. With this order, GE recorded more than 3 GW of orders in India with its 2.7 MW turbine and anticipates crossing 5 GW of onshore wind installed base in the country by early 2024.” the company said.\nAmplus Solar’s wind farm will be commissioned by August 2024 and will provide accessible, affordable, and reliable green energy to local businesses and consumers, it added.\nDeepak Maloo, Regional Sales Leader for GE Vernova’s onshore wind business in Asia Pacific said, “GE has demonstrated expertise in India, having installed over 50 per cent of new wind capacity in the country last year. We are thankful to Amplus Solar for entrusting us with their first wind farm and look forward to furthering our partnership as the company continues to build its renewable energy portfolio under the leadership of Petronas.”\nAmplus Solar CEO, Sharad Pungalia, said, “We are happy to have found an experienced partner GE Vernova as we take another step in contributing to the country’s net-zero targets with our first wind-power project. We are confident that together, we can create the synergies needed for the successful completion of this project.”\nGE Vernova’s 2.7-132 wind turbine has proven to be the technology of choice for many customers in India due to its industry leading performance at India’s low wind speeds.\nThe project will leverage GE’s significant local footprint in India with product design primaril ...
#  GraphDocument(nodes=[Node(id='Flipkart', type='Organization'), Node(id='Polygon Labs', type='Organization'), Node(id='Hang', type='Organization'), Node(id='Firedrops 2.0', type='Program'), Node(id='Naren Ravula', type='Person', properties={'description': 'VP, Head of Product Strategy and Deployment at Flipkart'}), Node(id='Matt Smolin', type='Person', properties={'description': 'CEO and founder of Hang'}), Node(id='Nft', type='Technology'), Node(id='Web3', type='Technology')], relationships=[Relationship(source=Node(id='Flipkart', type='Organization'), target=Node(id='Polygon Labs', type='Organization'), type='PARTNER'), Relationship(source=Node(id='Flipkart', type='Organization'), target=Node(id='Hang', type='Organization'), type='PARTNER'), Relationship(source=Node(id='Flipkart', type='Organization'), target=Node(id='Firedrops 2.0', type='Program'), type='LAUNCH'), Relationship(source=Node(id='Firedrops 2.0', type='Program'), target=Node(id='Nft', type='Technology'), type='USE'), Relationship(source=Node(id='Firedrops 2.0', type='Program'), target=Node(id='Web3', type='Technology'), type='USE'), Relationship(source=Node(id='Naren Ravula', type='Person'), target=Node(id='Flipkart', type='Organization'), type='AFFILIATION'), Relationship(source=Node(id='Matt Smolin', type='Person'), target=Node(id='Hang', type='Organization'), type='AFFILIATION')], source=Document(page_content='E-commerce major Flipkart is partnering with Web3 start-up Polygon Labs and loyalty platform Hang to launch a loyalty program FireDrops 2.0, which incentivises brand loyalty through gamification.\nFireDrops will involve the community and use underlying NFT technology for rewards for a better user experience. NFTs enable easy ownership and redemption of rewards, thereby creating new revenue streams for brands and empowering customers to actively participate in the loyalty ecosystem.\nIt aims to provide an immersive experience to users. Surprises, games and rewards await users as they engage with their favourite brands in meaningful ways, earning exciting benefits and rewards. Quests and games related to their preferred brands allow users to earn membership passes, lifetime discounts and more.\nNaren Ravula, VP, Head of Product Strategy and Deployment at Flipkart, said, “By integrating Web3 and NFTs into brand loyalty programs, we are revolutionising brand marketing, storytelling and customer engagement. We recognise the value of customer loyalty and more importantly, the emerging space of Web3 loyalty. We are excited to partner with one of the best in the space for this innovative brand-first rewards and loyalty program.”\nBrand engagement\nThe program also plans to explore the launch of a dynamic marketplace that allows users to buy and sell rewards, adding flexibility and value to loyalty programs and fostering deeper brand engagement.\n“The world’s most innovative brands, like Flipkart, have a monumental opportunity to redefine how they connect with their customers and build loyalty. The best programs of the future will be gamified, personalised and Web3-enabled. The next generation of loyalty is here, and we are excited to partner with Flipkart to bring it to the masses,” said Matt Smolin, CEO and founder of Hang.')),
#  GraphDocument(nodes=[Node(id='State Street Corporation', type='Organization', properties={'description': 'A financial services and bank holding company listed on NYSE under the ticker STT.'}), Node(id='Benjamin Graham', type='Person', properties={'description': 'An economist and professional investor known for his work in value investing.'}), Node(id='Market Index Fund', type='Financial_instrument', properties={'description': 'A type of mutual fund designed to replicate the performance of a specific market index.'}), Node(id='Earnings Per Share (Eps)', type='Financial_metric', properties={'description': "A company's profit divided by the outstanding shares of its common stock."}), Node(id='Revenue', type='Financial_metric', properties={'description': "The total amount of income generated by the sale of goods or services related to the company's primary operations."}), Node(id='Share Price', type='Financial_metric', properties={'description': "The price of a single share of a company's stock."}), Node(id='Dividend', type='Financial_metric', properties={'description': "A distribution of a portion of a company's earnings to its shareholders."}), Node(id='Total Shareholder Return (Tsr)', type='Financial_metric', properties={'description': 'The total return of a stock to an investor, including both capital gains and dividends.'})], relationships=[Relationship(source=Node(id='State Street Corporation', type='Organization'), target=Node(id='Nyse', type='Organization'), type='LISTED_ON', properties={'description': 'State Street Corporation is listed on the New York Stock Exchange under the ticker STT.'}), Relationship(source=Node(id='State Street Corporation', type='Organization'), target=Node(id='Share Price', type='Financial_metric'), type='HAS', properties={'description': "State Street Corporation's share price has decreased by 25% over the last half decade."}), Relationship(source=Node(id='State Street Corporation', type='Organization'), target=Node(id='Share Price', type='Financial_metric'), type='HAS', properties={'description': "State Street Corporation's share price has increased by 9.8% in the last thirty days."}), Relationship(source=Node(id='State Street Corporation', type='Organization'), target=Node(id='Earnings Per Share (Eps)', type='Financial_metric'), type='HAS', properties={'description': "State Street Corporation's EPS has improved by 6.1% per year over the last half decade."}), Relationship(source=Node(id='State Street Corporation', type='Organization'), target=Node(id='Revenue', type='Financial_metric'), type='HAS', properties={'description': "State Street Corporation's revenue has increased by 0.5% over the last half decade."}), Relationship(source=Node(id='State Street Corporation', type='Organization'), target=Node(id='Total Shareholder Return (Tsr)', type='Financial_metric'), type='HAS', properties={'description': "State Street Corporation's total shareholder return is 22% over the last year."}), Relationship(source=Node(id='State Street Corporation', type='Organization'), target=Node(id='Dividend', type='Financial_metric'), type='HAS', properties={'description': "State Street Corporation's total shareholder return includes dividends."}), Relationship(source=Node(id='State Street Corporation', type='Organization'), target=Node(id='Market Index Fund', type='Financial_instrument'), type='COMPARED_TO', properties={'description': "State Street Corporation's performance is often compared to market index funds."}), Relationship(source=Node(id='Share Price', type='Financial_metric'), target=Node(id='Earnings Per Share (Eps)', type='Financial_metric'), type='COMPARED_TO', properties={'description': 'The share price of State Street Corporation is compared to its earnings per share (EPS) to understand market sentiment.'}), Relationship(source=Node(id='Share Price', type='Financial_metric'), target=Node(id='Revenue', type='Financial_metric'), type='COMPARED_TO', properties={'description': 'The share price of State Stree ...

# %%
from concurrent.futures import ThreadPoolExecutor

MAX_WORKERS = 10

def process_document(text):
    try:
        return llm_transformer.convert_to_graph_documents(
            [text]
        )
    except Exception as e:
        print(f"Error processing document with ID {text['id']}: {e}")
        return []

def multi_thread():
    graph_documents = []
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        # Submitting all tasks and creating a list of future objects
        futures = [executor.submit(process_document, text) for text in documents]

        for future in futures:
            graph_document = future.result()
            graph_documents.extend(graph_document)

# %time multi_thread()
# Out:
# CPU times: user 1.63 s, sys: 87.7 ms, total: 1.72 s
# Wall time: 23.3 s
