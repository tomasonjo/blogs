# %% [markdown]
# <a href="https://colab.research.google.com/github/tomasonjo/blogs/blob/master/pyg2neo/Movie_recommendations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sentence_transformers torch_geometric torch-scatter torch-sparse torch neo4j
# Out:
# Requirement already satisfied: sentence_transformers in c:\users\tomas\anaconda3\lib\site-packages (2.1.0)
# Requirement already satisfied: torch_geometric in c:\users\tomas\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: torch-scatter in c:\users\tomas\anaconda3\lib\site-packages (2.0.9)
# Requirement already satisfied: torch-sparse in c:\users\tomas\anaconda3\lib\site-packages (0.6.12)
# Requirement already satisfied: torch in c:\users\tomas\anaconda3\lib\site-packages (1.10.1)
# Requirement already satisfied: neo4j in c:\users\tomas\anaconda3\lib\site-packages (4.3.4)
# Requirement already satisfied: pytz in c:\users\tomas\anaconda3\lib\site-packages (from neo4j) (2021.1)
# Requirement already satisfied: nltk in c:\users\tomas\anaconda3\lib\site-packages (from sentence_transformers) (3.6.1)
# Requirement already satisfied: torchvision in c:\users\tomas\anaconda3\lib\site-packages (from sentence_transformers) (0.11.2)
# Requirement already satisfied: tokenizers>=0.10.3 in c:\users\tomas\anaconda3\lib\site-packages (from sentence_transformers) (0.10.3)
# Requirement already satisfied: huggingface-hub in c:\users\tomas\anaconda3\lib\site-packages (from sentence_transformers) (0.0.16)
# Requirement already satisfied: tqdm in c:\users\tomas\anaconda3\lib\site-packages (from sentence_transformers) (4.59.0)
# Requirement already satisfied: numpy in c:\users\tomas\anaconda3\lib\site-packages (from sentence_transformers) (1.20.1)
# Requirement already satisfied: scipy in c:\users\tomas\anaconda3\lib\site-packages (from sentence_transformers) (1.6.2)
# Requirement already satisfied: sentencepiece in c:\users\tomas\anaconda3\lib\site-packages (from sentence_transformers) (0.1.96)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\users\tomas\anaconda3\lib\site-packages (from sentence_transformers) (4.10.0)
# Requirement already satisfied: scikit-learn in c:\users\tomas\anaconda3\lib\site-packages (from sentence_transformers) (0.24.1)
# Requirement already satisfied: typing_extensions in c:\users\tomas\anaconda3\lib\site-packages (from torch) (3.7.4.3)
# Requirement already satisfied: filelock in c:\users\tomas\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (3.0.12)
# Requirement already satisfied: packaging in c:\users\tomas\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (20.9)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\tomas\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (5.4.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\tomas\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2021.4.4)
# Requirement already satisfied: requests in c:\users\tomas\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2.25.1)
# Requirement already satisfied: sacremoses in c:\users\tomas\anaconda3\lib\site-packages\sacremoses-0.0.43-py3.8.egg (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.0.43)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\tomas\anaconda3\lib\site-packages (from packaging->transformers<5.0.0,>=4.6.0->sentence_transformers) (2.4.7)
# Requirement already satisfied: yacs in c:\users\tomas\anaconda3\lib\site-packages (from torch_geometric) (0.1.8)
# Requirement already satisfied: networkx in c:\users\tomas\anaconda3\lib\site-packages (from torch_geometric) (2.5)
# Requirement already satisfied: rdflib in c:\users\tomas\anaconda3\lib\site-packages (from torch_geometric) (6.0.2)
# Requirement already satisfied: pandas in c:\users\tomas\anaconda3\lib\site-packages (from torch_geometric) (1.2.4)
# Requirement already satisfied: googledrivedownloader in c:\users\tomas\anaconda3\lib\site-packages (from torch_geometric) (0.4)
# Requirement already satisfied: jinja2 in c:\users\tomas\anaconda3\lib\site-packages (from torch_geometric) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\tomas\anaconda3\lib\site-packages (from jinja2->torch_geometric) (1.1.1)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\tomas\anaconda3\lib\site-packages (from networkx->torch_geometric) (5.0.6)
# Requirement already satisfied: joblib in c:\users\tomas\anaconda3\lib\site-packages (from nltk->sentence_transformers) (1.0.1)
# Requirement already satisfied: click in c:\users\tomas\anaconda3\lib\site-packages (from nltk->sentence_transformers) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\tomas\anaconda3\lib\site-packages (from pandas->torch_geometric) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\tomas\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->torch_geometric) (1.15.0)
# Requirement already satisfied: isodate in c:\users\tomas\anaconda3\lib\site-packages (from rdflib->torch_geometric) (0.6.0)
# Requirement already satisfied: setuptools in c:\users\tomas\anaconda3\lib\site-packages (from rdflib->torch_geometric) (52.0.0.post20210125)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\tomas\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\tomas\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tomas\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tomas\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (1.26.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tomas\anaconda3\lib\site-packages (from scikit-learn->sentence_transformers) (2.1.0)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in c:\users\tomas\anaconda3\lib\site-packages (from torchvision->sentence_transformers) (8.2.0)

# %%
import torch
import pandas as pd
import numpy as np
from torch.nn import Linear
import torch.nn.functional as F
from sentence_transformers import SentenceTransformer

import torch_geometric.transforms as T
from torch_geometric.nn import SAGEConv, to_hetero

from torch_geometric.data import HeteroData
from torch_geometric.transforms import ToUndirected, RandomLinkSplit

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#device = 'cpu'

# %%
print(device)
# Out:
# cuda

# %%
from neo4j import GraphDatabase

url= 'bolt://3.86.43.255:7687'
user = 'neo4j'
password = 'company-science-journals'

driver = GraphDatabase.driver(url, auth=(user, password))

def fetch_data(query):
  with driver.session() as session:
    result = session.run(query)
    return pd.DataFrame([r.values() for r in result], columns=result.keys())

# %%
fetch_data("""
CALL gds.graph.create('movies', ['Movie', 'Person'], {ACTED_IN: {orientation:'UNDIRECTED'}, DIRECTED: {orientation:'UNDIRECTED'}})
""")
# Out:
#                                       nodeProjection  \
# 0  {'Movie': {'properties': {}, 'label': 'Movie'}...
#
#                               relationshipProjection graphName  nodeCount  \
# 0  {'DIRECTED': {'orientation': 'UNDIRECTED', 'ag...    movies      28172
#
#    relationshipCount  createMillis
# 0              91834           226

# %%
fetch_data("""
CALL gds.fastRP.write('movies', {writeProperty:'fastrp', embeddingDimension:56})
""")
# Out:
#    nodeCount  nodePropertiesWritten  createMillis  computeMillis  writeMillis  \
# 0      28172                  28172             0            489         4367
#
#                                        configuration
# 0  {'writeConcurrency': 4, 'normalizationStrength...

# %%
def load_node(cypher, index_col, encoders=None, **kwargs):
    df = fetch_data(cypher)
    df.set_index(index_col, inplace=True)
    mapping = {index: i for i, index in enumerate(df.index.unique())}
    x = None
    if encoders is not None:
        xs = [encoder(df[col]) for col, encoder in encoders.items()]
        x = torch.cat(xs, dim=-1)

    return x, mapping

# %%
def load_edge(cypher, src_index_col, src_mapping, dst_index_col, dst_mapping,
                  encoders=None, **kwargs):
    df = fetch_data(cypher)

    src = [src_mapping[index] for index in df[src_index_col]]
    dst = [dst_mapping[index] for index in df[dst_index_col]]
    edge_index = torch.tensor([src, dst])

    edge_attr = None
    if encoders is not None:
        edge_attrs = [encoder(df[col]) for col, encoder in encoders.items()]
        edge_attr = torch.cat(edge_attrs, dim=-1)

    return edge_index, edge_attr

# %%
class SequenceEncoder(object):
    # The 'SequenceEncoder' encodes raw column strings into embeddings.
    def __init__(self, model_name='all-MiniLM-L6-v2', device=None):
        self.device = device
        self.model = SentenceTransformer(model_name, device=device)

    @torch.no_grad()
    def __call__(self, df):
        x = self.model.encode(df.values, show_progress_bar=True,
                              convert_to_tensor=True, device=self.device)
        return x.cpu()

# %%
class GenresEncoder(object):
    # The 'GenreEncoder' splits the raw column strings by 'sep' and converts
    # individual elements to categorical labels.
    def __init__(self, sep='|'):
        self.sep = sep

    def __call__(self, df):
        genres = set(g for col in df.values for g in col.split(self.sep))
        mapping = {genre: i for i, genre in enumerate(genres)}

        x = torch.zeros(len(df), len(mapping))
        for i, col in enumerate(df.values):
            for genre in col.split(self.sep):
                x[i, mapping[genre]] = 1
        return x

# %%
class IdentityEncoder(object):
    # The 'IdentityEncoder' takes the raw column values and converts them to
    # PyTorch tensors.
    def __init__(self, dtype=None, is_list=False):
        self.dtype = dtype
        self.is_list = is_list

    def __call__(self, df):
        if self.is_list:
            return torch.stack([torch.tensor(el) for el in df.values])
        return torch.from_numpy(df.values).to(self.dtype)

# %%
user_x, user_mapping = load_node("MATCH (u:User) RETURN u.userId AS userId" , index_col='userId')

# %%
movie_query = """
MATCH (m:Movie)-[:IN_GENRE]->(genre:Genre)
WITH m, collect(genre.name) AS genres_list
RETURN m.movieId AS movieId, m.title AS title, apoc.text.join(genres_list, '|') AS genres, m.fastrp AS fastrp
"""

movie_x, movie_mapping = load_node(
    movie_query, 
    index_col='movieId', encoders={
        'title': SequenceEncoder(),
        'genres': GenresEncoder(),
        'fastrp': IdentityEncoder(is_list=True)
    })
# Out:
# Batches:   0%|          | 0/286 [00:00<?, ?it/s]

# %%
rating_query = """
MATCH (u:User)-[r:RATED]->(m:Movie) 
RETURN u.userId AS userId, m.movieId AS movieId, r.rating AS rating
"""

edge_index, edge_label = load_edge(
    rating_query,
    src_index_col='userId',
    src_mapping=user_mapping,
    dst_index_col='movieId',
    dst_mapping=movie_mapping,
    encoders={'rating': IdentityEncoder(dtype=torch.long)},
)

# %%
data = HeteroData()
data['user'].num_nodes = len(user_mapping)  # Users do not have any features.
# Add user node features for message passing:
data['user'].x = torch.eye(data['user'].num_nodes, device=device)
del data['user'].num_nodes

data['movie'].x = movie_x
data['user', 'rates', 'movie'].edge_index = edge_index
data['user', 'rates', 'movie'].edge_label = edge_label
data.to(device, non_blocking=True)
# Out:
# HeteroData(
#   user={ x=[671, 671] },
#   movie={ x=[9125, 460] },
#   (user, rates, movie)={
#     edge_index=[2, 100004],
#     edge_label=[100004]
#   }
# )

# %%
data = ToUndirected()(data)
del data['movie', 'rev_rates', 'user'].edge_label  # Remove "reverse" label.

# 2. Perform a link-level split into training, validation, and test edges.
transform = RandomLinkSplit(
    num_val=0.1,
    num_test=0.1,
    neg_sampling_ratio=0.0,
    edge_types=[('user', 'rates', 'movie')],
    rev_edge_types=[('movie', 'rev_rates', 'user')],
)
train_data, val_data, test_data = transform(data)

# %%
class GNNEncoder(torch.nn.Module):
    def __init__(self, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = SAGEConv((-1, -1), hidden_channels)
        self.conv2 = SAGEConv((-1, -1), out_channels)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        x = self.conv2(x, edge_index)
        return x


class EdgeDecoder(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        self.lin1 = Linear(2 * hidden_channels, hidden_channels)
        self.lin2 = Linear(hidden_channels, 1)

    def forward(self, z_dict, edge_label_index):
        row, col = edge_label_index
        z = torch.cat([z_dict['user'][row], z_dict['movie'][col]], dim=-1)

        z = self.lin1(z).relu()
        z = self.lin2(z)
        return z.view(-1)

# %%
class Model(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        self.encoder = GNNEncoder(hidden_channels, hidden_channels)
        self.encoder = to_hetero(self.encoder, data.metadata(), aggr='sum')
        self.decoder = EdgeDecoder(hidden_channels)

    def forward(self, x_dict, edge_index_dict, edge_label_index):
        z_dict = self.encoder(x_dict, edge_index_dict)
        return self.decoder(z_dict, edge_label_index)

# %%
model = Model(hidden_channels=64).to(device)

# %%
weight = torch.bincount(train_data['user', 'movie'].edge_label)
weight = weight.max() / weight

def weighted_mse_loss(pred, target, weight=None):
    weight = 1. if weight is None else weight[target].to(pred.dtype)
    return (weight * (pred - target.to(pred.dtype)).pow(2)).mean()

# %%
# Due to lazy initialization, we need to run one model step so the number
# of parameters can be inferred:
with torch.no_grad():
    model.encoder(train_data.x_dict, train_data.edge_index_dict)

optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
def train():
    model.train()
    optimizer.zero_grad()
    pred = model(train_data.x_dict, train_data.edge_index_dict,
                 train_data['user', 'rates', 'movie'].edge_label_index)
    target = train_data['user', 'rates', 'movie'].edge_label
    loss = weighted_mse_loss(pred, target, weight)
    loss.backward()
    optimizer.step()
    return float(loss)

# %%
@torch.no_grad()
def test(data):
    model.eval()
    pred = model(data.x_dict, data.edge_index_dict,
                 data['user', 'rates', 'movie'].edge_label_index)
    pred = pred.clamp(min=0, max=5)
    target = data['user', 'rates', 'movie'].edge_label.float()
    rmse = F.mse_loss(pred, target).sqrt()
    return float(rmse)

# %%
for epoch in range(1, 300):
    loss = train()
    train_rmse = test(train_data)
    val_rmse = test(val_data)
    test_rmse = test(test_data)
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Train: {train_rmse:.4f}, '
          f'Val: {val_rmse:.4f}, Test: {test_rmse:.4f}')
# Out:
# Epoch: 001, Loss: 20.4778, Train: 3.2648, Val: 3.2541, Test: 3.2599
# Epoch: 002, Loss: 16.5212, Train: 2.2975, Val: 2.2942, Test: 2.3017
# Epoch: 003, Loss: 8.9984, Train: 1.2526, Val: 1.2495, Test: 1.2641
# Epoch: 004, Loss: 11.1087, Train: 1.1689, Val: 1.1736, Test: 1.1874
# Epoch: 005, Loss: 6.8246, Train: 1.7622, Val: 1.7627, Test: 1.7714
# Epoch: 006, Loss: 6.7204, Train: 2.1124, Val: 2.1098, Test: 2.1169
# Epoch: 007, Loss: 7.9894, Train: 2.1377, Val: 2.1348, Test: 2.1416
# Epoch: 008, Loss: 8.0837, Train: 1.9314, Val: 1.9304, Test: 1.9373
# Epoch: 009, Loss: 7.1595, Train: 1.5597, Val: 1.5622, Test: 1.5699
# Epoch: 010, Loss: 6.0748, Train: 1.1838, Val: 1.1907, Test: 1.2001
# Epoch: 271, Loss: 2.2422, Train: 1.0134, Val: 1.1378, Test: 1.1080
# Epoch: 272, Loss: 2.2387, Train: 0.9986, Val: 1.1252, Test: 1.0957
# Epoch: 273, Loss: 2.2355, Train: 1.0008, Val: 1.1282, Test: 1.0983
# Epoch: 274, Loss: 2.2342, Train: 1.0080, Val: 1.1347, Test: 1.1047
# Epoch: 275, Loss: 2.2340, Train: 0.9945, Val: 1.1208, Test: 1.0919
# Epoch: 276, Loss: 2.2356, Train: 1.0165, Val: 1.1423, Test: 1.1124
# Epoch: 277, Loss: 2.2368, Train: 0.9872, Val: 1.1152, Test: 1.0865
# Epoch: 278, Loss: 2.2393, Train: 1.0224, Val: 1.1492, Test: 1.1190
# Epoch: 279, Loss: 2.2421, Train: 0.9820, Val: 1.1101, Test: 1.0817
# Epoch: 280, Loss: 2.2464, Train: 1.0303, Val: 1.1557, Test: 1.1256
# Epoch: 281, Loss: 2.2478, Train: 0.9803, Val: 1.1086, Test: 1.0804
# Epoch: 282, Loss: 2.2489, Train: 1.0274, Val: 1.1543, Test: 1.1241
# Epoch: 283, Loss: 2.2441, Train: 0.9827, Val: 1.1122, Test: 1.0838
# Epoch: 284, Loss: 2.2409, Train: 1.0208, Val: 1.1481, Test: 1.1184
# Epoch: 285, Loss: 2.2349, Train: 0.9904, Val: 1.1196, Test: 1.0912
# Epoch: 286, Loss: 2.2298, Train: 1.0083, Val: 1.1374, Test: 1.1081
# Epoch: 287, Loss: 2.2253, Train: 1.0005, Val: 1.1307, Test: 1.1017
# Epoch: 288, Loss: 2.2231, Train: 0.9970, Val: 1.1276, Test: 1.0987
# Epoch: 289, Loss: 2.2228, Train: 1.0107, Val: 1.1402, Test: 1.1109
# Epoch: 290, Loss: 2.2239, Train: 0.9885, Val: 1.1189, Test: 1.0907
# Epoch: 291, Loss: 2.2273, Train: 1.0233, Val: 1.1523, Test: 1.1227
# Epoch: 292, Loss: 2.2335, Train: 0.9753, Val: 1.1068, Test: 1.0790
# Epoch: 293, Loss: 2.2490, Train: 1.0508, Val: 1.1770, Test: 1.1474
# Epoch: 294, Loss: 2.2741, Train: 0.9604, Val: 1.0895, Test: 1.0629
# Epoch: 295, Loss: 2.3213, Train: 1.0784, Val: 1.1993, Test: 1.1704
# Epoch: 296, Loss: 2.3272, Train: 0.9612, Val: 1.0892, Test: 1.0627
# Epoch: 297, Loss: 2.3199, Train: 1.0367, Val: 1.1627, Test: 1.1338
# Epoch: 298, Loss: 2.2472, Train: 1.0005, Val: 1.1317, Test: 1.1029
# Epoch: 299, Loss: 2.2182, Train: 0.9767, Val: 1.1099, Test: 1.0821

# %%
num_movies = len(movie_mapping)
num_users = len(user_mapping)

for user_id in range(0,num_users): 

    row = torch.tensor([user_id] * num_movies)
    col = torch.arange(num_movies)
    edge_label_index = torch.stack([row, col], dim=0)

    pred = model(data.x_dict, data.edge_index_dict,
                 edge_label_index)
    pred = pred.clamp(min=0, max=5)
    mask = pred > 4
